# %% [markdown]
# ## Key components
# Reliable RAG is an improvement over naive RAG that addresses:
# 1. Retrieval of irrelevant documents
# 2. Hallucinations not grounded in facts from the retrieved information
# 3. Citation of sources used to generate the response
#
# How does it do this?
# 1. Use an LLM to filter retrieved documents
# 2. Something
# 3. Something

# %%
# !poetry add llama-index llama-index-readers-web
# Out:
# The following packages are already present in the pyproject.toml and will be skipped:
#
#   - llama-index
#
# If you want to update it to the latest compatible version, you can use `poetry update package`.
# If you prefer to upgrade it to the latest available version, you can use `poetry add package@latest`.
#
# Using version ^0.2.3 for llama-index-readers-web
#
# Updating dependencies
# Resolving dependencies... (24.7s)://files.pythonhosted.org/packages/a9/cb/2c8332bcdc14d33b0bedd18ae0a4981a069c3513e445120da3c3f23a8aaa/jieba3k-0.35.1.zip  93% (5.8s)Resolving dependencies... (8.6s)Resolving dependencies... (10.4s)Resolving dependencies... (12.4s)Resolving dependencies... (14.3s)Resolving dependencies... (14.6s)Resolving dependencies... (17.1s)Resolving dependencies... (19.1s)Resolving dependencies... (22.4s)Resolving dependencies... (22.7s)Resolving dependencies... (22.8s)Resolving dependencies... (23.3s)
#
# Package operations: 24 installs, 0 updates, 0 removals
#
#   - Installing outcome (1.3.0.post0): Pending...
#   - Installing sortedcontainers (2.4.0): Pending...
#   - Installing sortedcontainers (2.4.0): Downloading... 0%
#   - Installing sortedcontainers (2.4.0): Downloading... 0%
#   - Installing outcome (1.3.0.post0): Downloading... 0%
#   - Installing sortedcontainers (2.4.0): Downloading... 0%
#   - Installing sortedcontainers (2.4.0): Downloading... 0%
#   - Installing outcome (1.3.0.post0): Downloading... 100%
#   - Installing sortedcontainers (2.4.0): Downloading... 0%
#   - Installing sortedcontainers (2.4.0): Downloading... 0%
#   - Installing outcome (1.3.0.post0): Installing...
#   - Installing sortedcontainers (2.4.0): Downloading... 0%
#   - Installing sortedcontainers (2.4.0): Downloading... 100%
#   - Installing sortedcontainers (2.4.0): Installing...
#   - Installing sortedcontainers (2.4.0): Installing...
#   - Installing outcome (1.3.0.post0)
#   - Installing sortedcontainers (2.4.0): Installing...
#   - Installing sortedcontainers (2.4.0)
#   - Installing pysocks (1.7.1): Pending...
#   - Installing requests-file (2.1.0): Pending...
#   - Installing sgmllib3k (1.0.0): Pending...
#   - Installing trio (0.26.2): Pending...
#   - Installing wsproto (1.2.0): Pending...
#   - Installing wsproto (1.2.0): Downloading... 0%
#   - Installing trio (0.26.2): Pending...
#   - Installing wsproto (1.2.0): Downloading... 0%
#   - Installing sgmllib3k (1.0.0): Downloading... 0%
#   - Installing trio (0.26.2): Pending...
#   - Installing wsproto (1.2.0): Downloading... 0%
#   - Installing wsproto (1.2.0): Downloading... 100%
#   - Installing wsproto (1.2.0): Installing...
#   - Installing trio (0.26.2): Pending...
#   - Installing wsproto (1.2.0): Installing...
#   - Installing sgmllib3k (1.0.0): Downloading... 100%
#   - Installing trio (0.26.2): Pending...
#   - Installing wsproto (1.2.0): Installing...
#   - Installing trio (0.26.2): Pending...
#   - Installing wsproto (1.2.0): Installing...
#   - Installing sgmllib3k (1.0.0): Preparing...
#   - Installing trio (0.26.2): Pending...
#   - Installing wsproto (1.2.0): Installing...
#   - Installing wsproto (1.2.0)
#   - Installing requests-file (2.1.0): Pending...
#   - Installing sgmllib3k (1.0.0): Preparing...
#   - Installing trio (0.26.2): Pending...
#   - Installing wsproto (1.2.0)
#   - Installing pysocks (1.7.1): Downloading... 0%
#   - Installing requests-file (2.1.0): Pending...
#   - Installing sgmllib3k (1.0.0): Preparing...
#   - Installing trio (0.26.2): Pending...
#   - Installing wsproto (1.2.0)
#   - Installing sgmllib3k (1.0.0): Preparing...
#   - Installing trio (0.26.2): Pending...
#   - Installing wsproto (1.2.0)
#   - Installing requests-file (2.1.0): Downloading... 0%
#   - Installing sgmllib3k (1.0.0): Preparing...
#   - Installing trio (0.26.2): Pending...
#   - Installing wsproto (1.2.0)
#   - Installing wsproto (1.2.0)
#   - Installing trio (0.26.2): Downloading... 0%
#   - Installing wsproto (1.2.0)
#   - Installing requests-file (2.1.0): Downloading... 0%
#   - Installing sgmllib3k (1.0.0): Preparing...
#   - Installing trio (0.26.2): Downloading... 0%
#   - Installing wsproto (1.2.0)
#   - Installing pysocks (1.7.1): Downloading... 100%
#   - Installing requests-file (2.1.0): Downloading... 0%
#   - Installing sgmllib3k (1.0.0): Preparing...
#   - Installing trio (0.26.2): Downloading... 0%
#   - Installing wsproto (1.2.0)
#   - Installing sgmllib3k (1.0.0): Preparing...
#   - Installing trio (0.26.2): Downloading... 0%
#   - Installing wsproto (1.2.0)
#   - Installing requests-file (2.1.0): Downloading... 100%
#   - Installing sgmllib3k (1.0.0): Preparing...
#   - Installing trio (0.26.2): Downloading... 0%
#   - Installing wsproto (1.2.0)
#   - Installing requests-file (2.1.0): Downloading... 100%
#   - Installing sgmllib3k (1.0.0): Preparing...
#   - Installing trio (0.26.2): Downloading... 0%
#   - Installing wsproto (1.2.0)
#   - Installing pysocks (1.7.1): Installing...
#   - Installing requests-file (2.1.0): Downloading... 100%
#   - Installing sgmllib3k (1.0.0): Preparing...
#   - Installing trio (0.26.2): Downloading... 0%
#   - Installing wsproto (1.2.0)
#   - Installing sgmllib3k (1.0.0): Preparing...
#   - Installing trio (0.26.2): Downloading... 0%
#   - Installing wsproto (1.2.0)
#   - Installing requests-file (2.1.0): Installing...
#   - Installing sgmllib3k (1.0.0): Preparing...
#   - Installing trio (0.26.2): Downloading... 0%
#   - Installing wsproto (1.2.0)
#   - Installing sgmllib3k (1.0.0): Preparing...
#   - Installing trio (0.26.2): Downloading... 0%
#   - Installing wsproto (1.2.0)
#   - Installing requests-file (2.1.0)
#   - Installing sgmllib3k (1.0.0): Preparing...
#   - Installing trio (0.26.2): Downloading... 0%
#   - Installing wsproto (1.2.0)
#   - Installing requests-file (2.1.0)
#   - Installing sgmllib3k (1.0.0): Preparing...
#   - Installing trio (0.26.2): Downloading... 0%
#   - Installing wsproto (1.2.0)
#   - Installing pysocks (1.7.1)
#   - Installing requests-file (2.1.0)
#   - Installing sgmllib3k (1.0.0): Preparing...
#   - Installing trio (0.26.2): Downloading... 0%
#   - Installing wsproto (1.2.0)
#   - Installing wsproto (1.2.0)
#   - Installing trio (0.26.2): Downloading... 100%
#   - Installing wsproto (1.2.0)
#   - Installing wsproto (1.2.0)
#   - Installing trio (0.26.2): Installing...
#   - Installing wsproto (1.2.0)
#   - Installing wsproto (1.2.0)
#   - Installing trio (0.26.2)
#   - Installing wsproto (1.2.0)
#   - Installing trio (0.26.2)
#   - Installing wsproto (1.2.0)
#   - Installing sgmllib3k (1.0.0): Installing...
#   - Installing trio (0.26.2)
#   - Installing wsproto (1.2.0)
#   - Installing trio (0.26.2)
#   - Installing wsproto (1.2.0)
#   - Installing sgmllib3k (1.0.0)
#   - Installing trio (0.26.2)
#   - Installing wsproto (1.2.0)
#   - Installing cssselect (1.2.0): Pending...
#   - Installing feedfinder2 (0.0.4): Pending...
#   - Installing feedparser (6.0.11): Pending...
#   - Installing jieba3k (0.35.1): Pending...
#   - Installing lxml (5.3.0): Pending...
#   - Installing pyee (12.0.0): Pending...
#   - Installing tinysegmenter (0.3): Pending...
#   - Installing tldextract (5.1.2): Pending...
#   - Installing trio-websocket (0.11.1): Pending...
#   - Installing websocket-client (1.8.0): Pending...
#   - Installing websocket-client (1.8.0): Installing...
#   - Installing feedparser (6.0.11): Pending...
#   - Installing jieba3k (0.35.1): Pending...
#   - Installing lxml (5.3.0): Pending...
#   - Installing pyee (12.0.0): Pending...
#   - Installing tinysegmenter (0.3): Pending...
#   - Installing tldextract (5.1.2): Pending...
#   - Installing trio-websocket (0.11.1): Pending...
#   - Installing websocket-client (1.8.0): Installing...
#   - Installing feedfinder2 (0.0.4): Downloading... 0%
#   - Installing feedparser (6.0.11): Pending...
#   - Installing jieba3k (0.35.1): Pending...
#   - Installing lxml (5.3.0): Pending...
#   - Installing pyee (12.0.0): Pending...
#   - Installing tinysegmenter (0.3): Pending...
#   - Installing tldextract (5.1.2): Pending...
#   - Installing trio-websocket (0.11.1): Pending...
#   - Installing websocket-client (1.8.0): Installing...
#   - Installing tinysegmenter (0.3): Pending...
#   - Installing tldextract (5.1.2): Pending...
#   - Installing trio-websocket (0.11.1): Pending...
#   - Installing websocket-client (1.8.0): Installing...
#   - Installing pyee (12.0.0): Downloading... 0%
#   - Installing tinysegmenter (0.3): Pending...
#   - Installing tldextract (5.1.2): Pending...
#   - Installing trio-websocket (0.11.1): Pending...
#   - Installing websocket-client (1.8.0): Installing...
#   - Installing feedfinder2 (0.0.4): Downloading... 0%
#   - Installing feedparser (6.0.11): Pending...
#   - Installing jieba3k (0.35.1): Pending...
#   - Installing lxml (5.3.0): Pending...
#   - Installing pyee (12.0.0): Downloading... 0%
#   - Installing tinysegmenter (0.3): Pending...
#   - Installing tldextract (5.1.2): Pending...
#   - Installing trio-websocket (0.11.1): Pending...
#   - Installing websocket-client (1.8.0): Installing...
#   - Installing cssselect (1.2.0): Downloading... 0%
#   - Installing feedfinder2 (0.0.4): Downloading... 0%
#   - Installing feedparser (6.0.11): Pending...
#   - Installing jieba3k (0.35.1): Pending...
#   - Installing lxml (5.3.0): Pending...
#   - Installing pyee (12.0.0): Downloading... 0%
#   - Installing tinysegmenter (0.3): Pending...
#   - Installing tldextract (5.1.2): Pending...
#   - Installing trio-websocket (0.11.1): Pending...
#   - Installing websocket-client (1.8.0): Installing...
#   - Installing jieba3k (0.35.1): Pending...
#   - Installing lxml (5.3.0): Pending...
#   - Installing pyee (12.0.0): Downloading... 0%
#   - Installing tinysegmenter (0.3): Pending...
#   - Installing tldextract (5.1.2): Pending...
#   - Installing trio-websocket (0.11.1): Pending...
#   - Installing websocket-client (1.8.0): Installing...
#   - Installing feedparser (6.0.11): Downloading... 0%
#   - Installing jieba3k (0.35.1): Pending...
#   - Installing lxml (5.3.0): Pending...
#   - Installing pyee (12.0.0): Downloading... 0%
#   - Installing tinysegmenter (0.3): Pending...
#   - Installing tldextract (5.1.2): Pending...
#   - Installing trio-websocket (0.11.1): Pending...
#   - Installing websocket-client (1.8.0): Installing...
#   - Installing lxml (5.3.0): Pending...
#   - Installing pyee (12.0.0): Downloading... 0%
#   - Installing tinysegmenter (0.3): Pending...
#   - Installing tldextract (5.1.2): Pending...
#   - Installing trio-websocket (0.11.1): Pending...
#   - Installing websocket-client (1.8.0): Installing...
#   - Installing jieba3k (0.35.1): Downloading... 0%
#   - Installing lxml (5.3.0): Pending...
#   - Installing pyee (12.0.0): Downloading... 0%
#   - Installing tinysegmenter (0.3): Pending...
#   - Installing tldextract (5.1.2): Pending...
#   - Installing trio-websocket (0.11.1): Pending...
#   - Installing websocket-client (1.8.0): Installing...
#   - Installing feedparser (6.0.11): Downloading... 0%
#   - Installing jieba3k (0.35.1): Downloading... 0%
#   - Installing lxml (5.3.0): Pending...
#   - Installing pyee (12.0.0): Downloading... 0%
#   - Installing tinysegmenter (0.3): Pending...
#   - Installing tldextract (5.1.2): Pending...
#   - Installing trio-websocket (0.11.1): Pending...
#   - Installing websocket-client (1.8.0): Installing...
#   - Installing feedfinder2 (0.0.4): Downloading... 100%
#   - Installing feedparser (6.0.11): Downloading... 0%
#   - Installing jieba3k (0.35.1): Downloading... 0%
#   - Installing lxml (5.3.0): Pending...
#   - Installing pyee (12.0.0): Downloading... 0%
#   - Installing tinysegmenter (0.3): Pending...
#   - Installing tldextract (5.1.2): Pending...
#   - Installing trio-websocket (0.11.1): Pending...
#   - Installing websocket-client (1.8.0): Installing...
#   - Installing feedparser (6.0.11): Downloading... 0%
#   - Installing jieba3k (0.35.1): Downloading... 0%
#   - Installing lxml (5.3.0): Pending...
#   - Installing pyee (12.0.0): Downloading... 0%
#   - Installing tinysegmenter (0.3): Pending...
#   - Installing tldextract (5.1.2): Pending...
#   - Installing trio-websocket (0.11.1): Pending...
#   - Installing websocket-client (1.8.0): Installing...
#   - Installing feedfinder2 (0.0.4): Preparing...
#   - Installing feedparser (6.0.11): Downloading... 0%
#   - Installing jieba3k (0.35.1): Downloading... 0%
#   - Installing lxml (5.3.0): Pending...
#   - Installing pyee (12.0.0): Downloading... 0%
#   - Installing tinysegmenter (0.3): Pending...
#   - Installing tldextract (5.1.2): Pending...
#   - Installing trio-websocket (0.11.1): Pending...
#   - Installing websocket-client (1.8.0): Installing...
#   - Installing tinysegmenter (0.3): Pending...
#   - Installing tldextract (5.1.2): Pending...
#   - Installing trio-websocket (0.11.1): Pending...
#   - Installing websocket-client (1.8.0): Installing...
#   - Installing pyee (12.0.0): Downloading... 100%
#   - Installing tinysegmenter (0.3): Pending...
#   - Installing tldextract (5.1.2): Pending...
#   - Installing trio-websocket (0.11.1): Pending...
#   - Installing websocket-client (1.8.0): Installing...
#   - Installing feedfinder2 (0.0.4): Preparing...
#   - Installing feedparser (6.0.11): Downloading... 0%
#   - Installing jieba3k (0.35.1): Downloading... 0%
#   - Installing lxml (5.3.0): Pending...
#   - Installing pyee (12.0.0): Downloading... 100%
#   - Installing tinysegmenter (0.3): Pending...
#   - Installing tldextract (5.1.2): Pending...
#   - Installing trio-websocket (0.11.1): Pending...
#   - Installing websocket-client (1.8.0): Installing...
#   - Installing cssselect (1.2.0): Downloading... 100%
#   - Installing feedfinder2 (0.0.4): Preparing...
#   - Installing feedparser (6.0.11): Downloading... 0%
#   - Installing jieba3k (0.35.1): Downloading... 0%
#   - Installing lxml (5.3.0): Pending...
#   - Installing pyee (12.0.0): Downloading... 100%
#   - Installing tinysegmenter (0.3): Pending...
#   - Installing tldextract (5.1.2): Pending...
#   - Installing trio-websocket (0.11.1): Pending...
#   - Installing websocket-client (1.8.0): Installing...
#   - Installing feedfinder2 (0.0.4): Preparing...
#   - Installing feedparser (6.0.11): Downloading... 0%
#   - Installing jieba3k (0.35.1): Downloading... 0%
#   - Installing lxml (5.3.0): Pending...
#   - Installing pyee (12.0.0): Downloading... 100%
#   - Installing tinysegmenter (0.3): Pending...
#   - Installing tldextract (5.1.2): Pending...
#   - Installing trio-websocket (0.11.1): Pending...
#   - Installing websocket-client (1.8.0): Installing...
#   - Installing cssselect (1.2.0): Installing...
#   - Installing feedfinder2 (0.0.4): Preparing...
#   - Installing feedparser (6.0.11): Downloading... 0%
#   - Installing jieba3k (0.35.1): Downloading... 0%
#   - Installing lxml (5.3.0): Pending...
#   - Installing pyee (12.0.0): Downloading... 100%
#   - Installing tinysegmenter (0.3): Pending...
#   - Installing tldextract (5.1.2): Pending...
#   - Installing trio-websocket (0.11.1): Pending...
#   - Installing websocket-client (1.8.0): Installing...
#   - Installing tinysegmenter (0.3): Pending...
#   - Installing tldextract (5.1.2): Pending...
#   - Installing trio-websocket (0.11.1): Pending...
#   - Installing websocket-client (1.8.0): Installing...
#   - Installing pyee (12.0.0): Installing...
#   - Installing tinysegmenter (0.3): Pending...
#   - Installing tldextract (5.1.2): Pending...
#   - Installing trio-websocket (0.11.1): Pending...
#   - Installing websocket-client (1.8.0): Installing...
#   - Installing pyee (12.0.0): Installing...
#   - Installing tinysegmenter (0.3): Pending...
#   - Installing tldextract (5.1.2): Pending...
#   - Installing trio-websocket (0.11.1): Pending...
#   - Installing websocket-client (1.8.0): Installing...
#   - Installing lxml (5.3.0): Downloading... 0%
#   - Installing pyee (12.0.0): Installing...
#   - Installing tinysegmenter (0.3): Pending...
#   - Installing tldextract (5.1.2): Pending...
#   - Installing trio-websocket (0.11.1): Pending...
#   - Installing websocket-client (1.8.0): Installing...
#   - Installing trio-websocket (0.11.1): Pending...
#   - Installing websocket-client (1.8.0): Installing...
#   - Installing tldextract (5.1.2): Downloading... 0%
#   - Installing trio-websocket (0.11.1): Pending...
#   - Installing websocket-client (1.8.0): Installing...
#   - Installing jieba3k (0.35.1): Downloading... 0%
#   - Installing lxml (5.3.0): Downloading... 0%
#   - Installing pyee (12.0.0): Installing...
#   - Installing tinysegmenter (0.3): Pending...
#   - Installing tldextract (5.1.2): Downloading... 0%
#   - Installing trio-websocket (0.11.1): Pending...
#   - Installing websocket-client (1.8.0): Installing...
#   - Installing feedparser (6.0.11): Downloading... 100%
#   - Installing jieba3k (0.35.1): Downloading... 0%
#   - Installing lxml (5.3.0): Downloading... 0%
#   - Installing pyee (12.0.0): Installing...
#   - Installing tinysegmenter (0.3): Pending...
#   - Installing tldextract (5.1.2): Downloading... 0%
#   - Installing trio-websocket (0.11.1): Pending...
#   - Installing websocket-client (1.8.0): Installing...
#   - Installing websocket-client (1.8.0)
#   - Installing jieba3k (0.35.1): Downloading... 0%
#   - Installing lxml (5.3.0): Downloading... 0%
#   - Installing pyee (12.0.0): Installing...
#   - Installing tinysegmenter (0.3): Pending...
#   - Installing tldextract (5.1.2): Downloading... 0%
#   - Installing trio-websocket (0.11.1): Pending...
#   - Installing websocket-client (1.8.0)
#   - Installing feedparser (6.0.11): Installing...
#   - Installing jieba3k (0.35.1): Downloading... 0%
#   - Installing lxml (5.3.0): Downloading... 0%
#   - Installing pyee (12.0.0): Installing...
#   - Installing tinysegmenter (0.3): Pending...
#   - Installing tldextract (5.1.2): Downloading... 0%
#   - Installing trio-websocket (0.11.1): Pending...
#   - Installing websocket-client (1.8.0)
#   - Installing feedfinder2 (0.0.4): Preparing...
#   - Installing feedparser (6.0.11): Installing...
#   - Installing jieba3k (0.35.1): Downloading... 0%
#   - Installing lxml (5.3.0): Downloading... 0%
#   - Installing pyee (12.0.0): Installing...
#   - Installing tinysegmenter (0.3): Pending...
#   - Installing tldextract (5.1.2): Downloading... 0%
#   - Installing trio-websocket (0.11.1): Pending...
#   - Installing websocket-client (1.8.0)
#   - Installing cssselect (1.2.0)
#   - Installing feedfinder2 (0.0.4): Preparing...
#   - Installing feedparser (6.0.11): Installing...
#   - Installing jieba3k (0.35.1): Downloading... 0%
#   - Installing lxml (5.3.0): Downloading... 0%
#   - Installing pyee (12.0.0): Installing...
#   - Installing tinysegmenter (0.3): Pending...
#   - Installing tldextract (5.1.2): Downloading... 0%
#   - Installing trio-websocket (0.11.1): Pending...
#   - Installing websocket-client (1.8.0)
#   - Installing tinysegmenter (0.3): Pending...
#   - Installing tldextract (5.1.2): Downloading... 0%
#   - Installing trio-websocket (0.11.1): Pending...
#   - Installing websocket-client (1.8.0)
#   - Installing pyee (12.0.0)
#   - Installing tinysegmenter (0.3): Pending...
#   - Installing tldextract (5.1.2): Downloading... 0%
#   - Installing trio-websocket (0.11.1): Pending...
#   - Installing websocket-client (1.8.0)
#   - Installing websocket-client (1.8.0)
#   - Installing trio-websocket (0.11.1): Downloading... 0%
#   - Installing websocket-client (1.8.0)
#   - Installing tldextract (5.1.2): Downloading... 0%
#   - Installing trio-websocket (0.11.1): Downloading... 0%
#   - Installing websocket-client (1.8.0)
#   - Installing tinysegmenter (0.3): Downloading... 0%
#   - Installing tldextract (5.1.2): Downloading... 0%
#   - Installing trio-websocket (0.11.1): Downloading... 0%
#   - Installing websocket-client (1.8.0)
#   - Installing websocket-client (1.8.0)
#   - Installing trio-websocket (0.11.1): Downloading... 100%
#   - Installing websocket-client (1.8.0)
#   - Installing websocket-client (1.8.0)
#   - Installing trio-websocket (0.11.1): Installing...
#   - Installing websocket-client (1.8.0)
#   - Installing tldextract (5.1.2): Downloading... 0%
#   - Installing trio-websocket (0.11.1): Installing...
#   - Installing websocket-client (1.8.0)
#   - Installing tinysegmenter (0.3): Downloading... 100%
#   - Installing tldextract (5.1.2): Downloading... 0%
#   - Installing trio-websocket (0.11.1): Installing...
#   - Installing websocket-client (1.8.0)
#   - Installing tldextract (5.1.2): Downloading... 0%
#   - Installing trio-websocket (0.11.1): Installing...
#   - Installing websocket-client (1.8.0)
#   - Installing tinysegmenter (0.3): Preparing...
#   - Installing tldextract (5.1.2): Downloading... 0%
#   - Installing trio-websocket (0.11.1): Installing...
#   - Installing websocket-client (1.8.0)
#   - Installing trio-websocket (0.11.1): Installing...
#   - Installing websocket-client (1.8.0)
#   - Installing tldextract (5.1.2): Downloading... 100%
#   - Installing trio-websocket (0.11.1): Installing...
#   - Installing websocket-client (1.8.0)
#   - Installing trio-websocket (0.11.1): Installing...
#   - Installing websocket-client (1.8.0)
#   - Installing tldextract (5.1.2): Installing...
#   - Installing trio-websocket (0.11.1): Installing...
#   - Installing websocket-client (1.8.0)
#   - Installing websocket-client (1.8.0)
#   - Installing trio-websocket (0.11.1)
#   - Installing websocket-client (1.8.0)
#   - Installing jieba3k (0.35.1): Downloading... 0%
#   - Installing lxml (5.3.0): Downloading... 0%
#   - Installing pyee (12.0.0)
#   - Installing tinysegmenter (0.3): Preparing...
#   - Installing tldextract (5.1.2): Installing...
#   - Installing trio-websocket (0.11.1)
#   - Installing websocket-client (1.8.0)
#   - Installing feedparser (6.0.11)
#   - Installing jieba3k (0.35.1): Downloading... 0%
#   - Installing lxml (5.3.0): Downloading... 0%
#   - Installing pyee (12.0.0)
#   - Installing tinysegmenter (0.3): Preparing...
#   - Installing tldextract (5.1.2): Installing...
#   - Installing trio-websocket (0.11.1)
#   - Installing websocket-client (1.8.0)
#   - Installing trio-websocket (0.11.1)
#   - Installing websocket-client (1.8.0)
#   - Installing tldextract (5.1.2)
#   - Installing trio-websocket (0.11.1)
#   - Installing websocket-client (1.8.0)
#   - Installing lxml (5.3.0): Downloading... 0%
#   - Installing pyee (12.0.0)
#   - Installing tinysegmenter (0.3): Preparing...
#   - Installing tldextract (5.1.2)
#   - Installing trio-websocket (0.11.1)
#   - Installing websocket-client (1.8.0)
#   - Installing jieba3k (0.35.1): Downloading... 20%
#   - Installing lxml (5.3.0): Downloading... 0%
#   - Installing pyee (12.0.0)
#   - Installing tinysegmenter (0.3): Preparing...
#   - Installing tldextract (5.1.2)
#   - Installing trio-websocket (0.11.1)
#   - Installing websocket-client (1.8.0)
#   - Installing pyee (12.0.0)
#   - Installing tinysegmenter (0.3): Preparing...
#   - Installing tldextract (5.1.2)
#   - Installing trio-websocket (0.11.1)
#   - Installing websocket-client (1.8.0)
#   - Installing lxml (5.3.0): Downloading... 20%
#   - Installing pyee (12.0.0)
#   - Installing tinysegmenter (0.3): Preparing...
#   - Installing tldextract (5.1.2)
#   - Installing trio-websocket (0.11.1)
#   - Installing websocket-client (1.8.0)
#   - Installing pyee (12.0.0)
#   - Installing tinysegmenter (0.3): Preparing...
#   - Installing tldextract (5.1.2)
#   - Installing trio-websocket (0.11.1)
#   - Installing websocket-client (1.8.0)
#   - Installing lxml (5.3.0): Downloading... 40%
#   - Installing pyee (12.0.0)
#   - Installing tinysegmenter (0.3): Preparing...
#   - Installing tldextract (5.1.2)
#   - Installing trio-websocket (0.11.1)
#   - Installing websocket-client (1.8.0)
#   - Installing lxml (5.3.0): Downloading... 40%
#   - Installing pyee (12.0.0)
#   - Installing tinysegmenter (0.3): Preparing...
#   - Installing tldextract (5.1.2)
#   - Installing trio-websocket (0.11.1)
#   - Installing websocket-client (1.8.0)
#   - Installing jieba3k (0.35.1): Downloading... 60%
#   - Installing lxml (5.3.0): Downloading... 40%
#   - Installing pyee (12.0.0)
#   - Installing tinysegmenter (0.3): Preparing...
#   - Installing tldextract (5.1.2)
#   - Installing trio-websocket (0.11.1)
#   - Installing websocket-client (1.8.0)
#   - Installing lxml (5.3.0): Downloading... 40%
#   - Installing pyee (12.0.0)
#   - Installing tinysegmenter (0.3): Preparing...
#   - Installing tldextract (5.1.2)
#   - Installing trio-websocket (0.11.1)
#   - Installing websocket-client (1.8.0)
#   - Installing jieba3k (0.35.1): Downloading... 100%
#   - Installing lxml (5.3.0): Downloading... 40%
#   - Installing pyee (12.0.0)
#   - Installing tinysegmenter (0.3): Preparing...
#   - Installing tldextract (5.1.2)
#   - Installing trio-websocket (0.11.1)
#   - Installing websocket-client (1.8.0)
#   - Installing lxml (5.3.0): Downloading... 40%
#   - Installing pyee (12.0.0)
#   - Installing tinysegmenter (0.3): Preparing...
#   - Installing tldextract (5.1.2)
#   - Installing trio-websocket (0.11.1)
#   - Installing websocket-client (1.8.0)
#   - Installing jieba3k (0.35.1): Preparing...
#   - Installing lxml (5.3.0): Downloading... 40%
#   - Installing pyee (12.0.0)
#   - Installing tinysegmenter (0.3): Preparing...
#   - Installing tldextract (5.1.2)
#   - Installing trio-websocket (0.11.1)
#   - Installing websocket-client (1.8.0)
#   - Installing pyee (12.0.0)
#   - Installing tinysegmenter (0.3): Preparing...
#   - Installing tldextract (5.1.2)
#   - Installing trio-websocket (0.11.1)
#   - Installing websocket-client (1.8.0)
#   - Installing lxml (5.3.0): Downloading... 100%
#   - Installing pyee (12.0.0)
#   - Installing tinysegmenter (0.3): Preparing...
#   - Installing tldextract (5.1.2)
#   - Installing trio-websocket (0.11.1)
#   - Installing websocket-client (1.8.0)
#   - Installing pyee (12.0.0)
#   - Installing tinysegmenter (0.3): Preparing...
#   - Installing tldextract (5.1.2)
#   - Installing trio-websocket (0.11.1)
#   - Installing websocket-client (1.8.0)
#   - Installing lxml (5.3.0): Installing...
#   - Installing pyee (12.0.0)
#   - Installing tinysegmenter (0.3): Preparing...
#   - Installing tldextract (5.1.2)
#   - Installing trio-websocket (0.11.1)
#   - Installing websocket-client (1.8.0)
#   - Installing pyee (12.0.0)
#   - Installing tinysegmenter (0.3): Preparing...
#   - Installing tldextract (5.1.2)
#   - Installing trio-websocket (0.11.1)
#   - Installing websocket-client (1.8.0)
#   - Installing lxml (5.3.0)
#   - Installing pyee (12.0.0)
#   - Installing tinysegmenter (0.3): Preparing...
#   - Installing tldextract (5.1.2)
#   - Installing trio-websocket (0.11.1)
#   - Installing websocket-client (1.8.0)
#   - Installing feedparser (6.0.11)
#   - Installing jieba3k (0.35.1): Preparing...
#   - Installing lxml (5.3.0)
#   - Installing pyee (12.0.0)
#   - Installing tinysegmenter (0.3): Preparing...
#   - Installing tldextract (5.1.2)
#   - Installing trio-websocket (0.11.1)
#   - Installing websocket-client (1.8.0)
#   - Installing feedfinder2 (0.0.4): Installing...
#   - Installing feedparser (6.0.11)
#   - Installing jieba3k (0.35.1): Preparing...
#   - Installing lxml (5.3.0)
#   - Installing pyee (12.0.0)
#   - Installing tinysegmenter (0.3): Preparing...
#   - Installing tldextract (5.1.2)
#   - Installing trio-websocket (0.11.1)
#   - Installing websocket-client (1.8.0)
#   - Installing feedparser (6.0.11)
#   - Installing jieba3k (0.35.1): Preparing...
#   - Installing lxml (5.3.0)
#   - Installing pyee (12.0.0)
#   - Installing tinysegmenter (0.3): Preparing...
#   - Installing tldextract (5.1.2)
#   - Installing trio-websocket (0.11.1)
#   - Installing websocket-client (1.8.0)
#   - Installing feedfinder2 (0.0.4)
#   - Installing feedparser (6.0.11)
#   - Installing jieba3k (0.35.1): Preparing...
#   - Installing lxml (5.3.0)
#   - Installing pyee (12.0.0)
#   - Installing tinysegmenter (0.3): Preparing...
#   - Installing tldextract (5.1.2)
#   - Installing trio-websocket (0.11.1)
#   - Installing websocket-client (1.8.0)
#   - Installing tldextract (5.1.2)
#   - Installing trio-websocket (0.11.1)
#   - Installing websocket-client (1.8.0)
#   - Installing tinysegmenter (0.3): Installing...
#   - Installing tldextract (5.1.2)
#   - Installing trio-websocket (0.11.1)
#   - Installing websocket-client (1.8.0)
#   - Installing tldextract (5.1.2)
#   - Installing trio-websocket (0.11.1)
#   - Installing websocket-client (1.8.0)
#   - Installing tinysegmenter (0.3)
#   - Installing tldextract (5.1.2)
#   - Installing trio-websocket (0.11.1)
#   - Installing websocket-client (1.8.0)
#   - Installing lxml (5.3.0)
#   - Installing pyee (12.0.0)
#   - Installing tinysegmenter (0.3)
#   - Installing tldextract (5.1.2)
#   - Installing trio-websocket (0.11.1)
#   - Installing websocket-client (1.8.0)
#   - Installing jieba3k (0.35.1): Installing...
#   - Installing lxml (5.3.0)
#   - Installing pyee (12.0.0)
#   - Installing tinysegmenter (0.3)
#   - Installing tldextract (5.1.2)
#   - Installing trio-websocket (0.11.1)
#   - Installing websocket-client (1.8.0)
#   - Installing lxml (5.3.0)
#   - Installing pyee (12.0.0)
#   - Installing tinysegmenter (0.3)
#   - Installing tldextract (5.1.2)
#   - Installing trio-websocket (0.11.1)
#   - Installing websocket-client (1.8.0)
#   - Installing jieba3k (0.35.1)
#   - Installing lxml (5.3.0)
#   - Installing pyee (12.0.0)
#   - Installing tinysegmenter (0.3)
#   - Installing tldextract (5.1.2)
#   - Installing trio-websocket (0.11.1)
#   - Installing websocket-client (1.8.0)
#   - Installing chromedriver-autoinstaller (0.6.4): Pending...
#   - Installing html2text (2024.2.26): Pending...
#   - Installing newspaper3k (0.2.8): Pending...
#   - Installing playwright (1.47.0): Pending...
#   - Installing selenium (4.25.0): Pending...
#   - Installing spider-client (0.0.27): Pending...
#   - Installing playwright (1.47.0): Pending...
#   - Installing selenium (4.25.0): Pending...
#   - Installing spider-client (0.0.27): Pending...
#   - Installing newspaper3k (0.2.8): Downloading... 0%
#   - Installing playwright (1.47.0): Pending...
#   - Installing selenium (4.25.0): Pending...
#   - Installing spider-client (0.0.27): Pending...
#   - Installing selenium (4.25.0): Pending...
#   - Installing spider-client (0.0.27): Pending...
#   - Installing playwright (1.47.0): Downloading... 0%
#   - Installing selenium (4.25.0): Pending...
#   - Installing spider-client (0.0.27): Pending...
#   - Installing html2text (2024.2.26): Pending...
#   - Installing newspaper3k (0.2.8): Downloading... 0%
#   - Installing playwright (1.47.0): Downloading... 0%
#   - Installing selenium (4.25.0): Pending...
#   - Installing spider-client (0.0.27): Pending...
#   - Installing chromedriver-autoinstaller (0.6.4): Downloading... 0%
#   - Installing html2text (2024.2.26): Pending...
#   - Installing newspaper3k (0.2.8): Downloading... 0%
#   - Installing playwright (1.47.0): Downloading... 0%
#   - Installing selenium (4.25.0): Pending...
#   - Installing spider-client (0.0.27): Pending...
#   - Installing spider-client (0.0.27): Downloading... 0%
#   - Installing spider-client (0.0.27): Downloading... 0%
#   - Installing selenium (4.25.0): Downloading... 0%
#   - Installing spider-client (0.0.27): Downloading... 0%
#   - Installing newspaper3k (0.2.8): Downloading... 0%
#   - Installing playwright (1.47.0): Downloading... 0%
#   - Installing selenium (4.25.0): Downloading... 0%
#   - Installing spider-client (0.0.27): Downloading... 0%
#   - Installing html2text (2024.2.26): Downloading... 0%
#   - Installing newspaper3k (0.2.8): Downloading... 0%
#   - Installing playwright (1.47.0): Downloading... 0%
#   - Installing selenium (4.25.0): Downloading... 0%
#   - Installing spider-client (0.0.27): Downloading... 0%
#   - Installing playwright (1.47.0): Downloading... 0%
#   - Installing selenium (4.25.0): Downloading... 0%
#   - Installing spider-client (0.0.27): Downloading... 0%
#   - Installing newspaper3k (0.2.8): Downloading... 100%
#   - Installing playwright (1.47.0): Downloading... 0%
#   - Installing selenium (4.25.0): Downloading... 0%
#   - Installing spider-client (0.0.27): Downloading... 0%
#   - Installing html2text (2024.2.26): Downloading... 0%
#   - Installing newspaper3k (0.2.8): Downloading... 100%
#   - Installing playwright (1.47.0): Downloading... 0%
#   - Installing selenium (4.25.0): Downloading... 0%
#   - Installing spider-client (0.0.27): Downloading... 0%
#   - Installing chromedriver-autoinstaller (0.6.4): Downloading... 100%
#   - Installing html2text (2024.2.26): Downloading... 0%
#   - Installing newspaper3k (0.2.8): Downloading... 100%
#   - Installing playwright (1.47.0): Downloading... 0%
#   - Installing selenium (4.25.0): Downloading... 0%
#   - Installing spider-client (0.0.27): Downloading... 0%
#   - Installing spider-client (0.0.27): Downloading... 100%
#   - Installing html2text (2024.2.26): Downloading... 0%
#   - Installing newspaper3k (0.2.8): Downloading... 100%
#   - Installing playwright (1.47.0): Downloading... 0%
#   - Installing selenium (4.25.0): Downloading... 0%
#   - Installing spider-client (0.0.27): Downloading... 100%
#   - Installing chromedriver-autoinstaller (0.6.4): Installing...
#   - Installing html2text (2024.2.26): Downloading... 0%
#   - Installing newspaper3k (0.2.8): Downloading... 100%
#   - Installing playwright (1.47.0): Downloading... 0%
#   - Installing selenium (4.25.0): Downloading... 0%
#   - Installing spider-client (0.0.27): Downloading... 100%
#   - Installing newspaper3k (0.2.8): Downloading... 100%
#   - Installing playwright (1.47.0): Downloading... 0%
#   - Installing selenium (4.25.0): Downloading... 0%
#   - Installing spider-client (0.0.27): Downloading... 100%
#   - Installing html2text (2024.2.26): Downloading... 100%
#   - Installing newspaper3k (0.2.8): Downloading... 100%
#   - Installing playwright (1.47.0): Downloading... 0%
#   - Installing selenium (4.25.0): Downloading... 0%
#   - Installing spider-client (0.0.27): Downloading... 100%
#   - Installing spider-client (0.0.27): Preparing...
#   - Installing playwright (1.47.0): Downloading... 0%
#   - Installing selenium (4.25.0): Downloading... 0%
#   - Installing spider-client (0.0.27): Preparing...
#   - Installing newspaper3k (0.2.8): Installing...
#   - Installing playwright (1.47.0): Downloading... 0%
#   - Installing selenium (4.25.0): Downloading... 0%
#   - Installing spider-client (0.0.27): Preparing...
#   - Installing newspaper3k (0.2.8): Installing...
#   - Installing playwright (1.47.0): Downloading... 0%
#   - Installing selenium (4.25.0): Downloading... 0%
#   - Installing spider-client (0.0.27): Preparing...
#   - Installing html2text (2024.2.26): Preparing...
#   - Installing newspaper3k (0.2.8): Installing...
#   - Installing playwright (1.47.0): Downloading... 0%
#   - Installing selenium (4.25.0): Downloading... 0%
#   - Installing spider-client (0.0.27): Preparing...
#   - Installing html2text (2024.2.26): Preparing...
#   - Installing newspaper3k (0.2.8): Installing...
#   - Installing playwright (1.47.0): Downloading... 0%
#   - Installing selenium (4.25.0): Downloading... 0%
#   - Installing spider-client (0.0.27): Preparing...
#   - Installing chromedriver-autoinstaller (0.6.4)
#   - Installing html2text (2024.2.26): Preparing...
#   - Installing newspaper3k (0.2.8): Installing...
#   - Installing playwright (1.47.0): Downloading... 0%
#   - Installing selenium (4.25.0): Downloading... 0%
#   - Installing spider-client (0.0.27): Preparing...
#   - Installing playwright (1.47.0): Downloading... 0%
#   - Installing selenium (4.25.0): Downloading... 0%
#   - Installing spider-client (0.0.27): Preparing...
#   - Installing newspaper3k (0.2.8)
#   - Installing playwright (1.47.0): Downloading... 0%
#   - Installing selenium (4.25.0): Downloading... 0%
#   - Installing spider-client (0.0.27): Preparing...
#   - Installing selenium (4.25.0): Downloading... 0%
#   - Installing spider-client (0.0.27): Preparing...
#   - Installing playwright (1.47.0): Downloading... 10%
#   - Installing selenium (4.25.0): Downloading... 0%
#   - Installing spider-client (0.0.27): Preparing...
#   - Installing spider-client (0.0.27): Preparing...
#   - Installing selenium (4.25.0): Downloading... 20%
#   - Installing spider-client (0.0.27): Preparing...
#   - Installing selenium (4.25.0): Downloading... 20%
#   - Installing spider-client (0.0.27): Preparing...
#   - Installing playwright (1.47.0): Downloading... 20%
#   - Installing selenium (4.25.0): Downloading... 20%
#   - Installing spider-client (0.0.27): Preparing...
#   - Installing spider-client (0.0.27): Preparing...
#   - Installing selenium (4.25.0): Downloading... 40%
#   - Installing spider-client (0.0.27): Preparing...
#   - Installing selenium (4.25.0): Downloading... 40%
#   - Installing spider-client (0.0.27): Preparing...
#   - Installing playwright (1.47.0): Downloading... 30%
#   - Installing selenium (4.25.0): Downloading... 40%
#   - Installing spider-client (0.0.27): Preparing...
#   - Installing spider-client (0.0.27): Preparing...
#   - Installing selenium (4.25.0): Downloading... 100%
#   - Installing spider-client (0.0.27): Preparing...
#   - Installing spider-client (0.0.27): Preparing...
#   - Installing selenium (4.25.0): Installing...
#   - Installing spider-client (0.0.27): Preparing...
#   - Installing selenium (4.25.0): Installing...
#   - Installing spider-client (0.0.27): Preparing...
#   - Installing playwright (1.47.0): Downloading... 50%
#   - Installing selenium (4.25.0): Installing...
#   - Installing spider-client (0.0.27): Preparing...
#   - Installing spider-client (0.0.27): Installing...
#   - Installing spider-client (0.0.27)
#   - Installing selenium (4.25.0): Installing...
#   - Installing spider-client (0.0.27)
#   - Installing playwright (1.47.0): Downloading... 60%
#   - Installing selenium (4.25.0): Installing...
#   - Installing spider-client (0.0.27)
#   - Installing spider-client (0.0.27)
#   - Installing selenium (4.25.0)
#   - Installing spider-client (0.0.27)
#   - Installing newspaper3k (0.2.8)
#   - Installing playwright (1.47.0): Downloading... 60%
#   - Installing selenium (4.25.0)
#   - Installing spider-client (0.0.27)
#   - Installing html2text (2024.2.26): Installing...
#   - Installing newspaper3k (0.2.8)
#   - Installing playwright (1.47.0): Downloading... 60%
#   - Installing selenium (4.25.0)
#   - Installing spider-client (0.0.27)
#   - Installing newspaper3k (0.2.8)
#   - Installing playwright (1.47.0): Downloading... 60%
#   - Installing selenium (4.25.0)
#   - Installing spider-client (0.0.27)
#   - Installing html2text (2024.2.26)
#   - Installing newspaper3k (0.2.8)
#   - Installing playwright (1.47.0): Downloading... 60%
#   - Installing selenium (4.25.0)
#   - Installing spider-client (0.0.27)
#   - Installing selenium (4.25.0)
#   - Installing spider-client (0.0.27)
#   - Installing playwright (1.47.0): Downloading... 80%
#   - Installing selenium (4.25.0)
#   - Installing spider-client (0.0.27)
#   - Installing selenium (4.25.0)
#   - Installing spider-client (0.0.27)
#   - Installing playwright (1.47.0): Downloading... 100%
#   - Installing selenium (4.25.0)
#   - Installing spider-client (0.0.27)
#   - Installing selenium (4.25.0)
#   - Installing spider-client (0.0.27)
#   - Installing playwright (1.47.0): Installing...
#   - Installing selenium (4.25.0)
#   - Installing spider-client (0.0.27)
#   - Installing selenium (4.25.0)
#   - Installing spider-client (0.0.27)
#   - Installing playwright (1.47.0)
#   - Installing selenium (4.25.0)
#   - Installing spider-client (0.0.27)
#   - Installing llama-index-readers-web (0.2.3): Pending...
#   - Installing llama-index-readers-web (0.2.3): Downloading... 0%
#   - Installing llama-index-readers-web (0.2.3): Downloading... 100%
#   - Installing llama-index-readers-web (0.2.3): Installing...
#   - Installing llama-index-readers-web (0.2.3)
#
# Writing lock file

# %%
# !poetry add llama-index-vector-stores-chroma
# Out:
# Using version ^0.2.0 for llama-index-vector-stores-chroma
#
# Updating dependencies
# Resolving dependencies... (8.3s)Resolving dependencies... (2.8s)Resolving dependencies... (4.3s)Resolving dependencies... (4.4s)Resolving dependencies... (4.5s)Resolving dependencies... (4.8s)Resolving dependencies... (4.9s)Resolving dependencies... (6.3s)Resolving dependencies... (6.6s)Resolving dependencies... (6.7s)Resolving dependencies... (7.1s)Resolving dependencies... (7.3s)Resolving dependencies... (7.4s)
#
# Package operations: 38 installs, 0 updates, 0 removals
#
#   - Installing pyasn1 (0.6.1): Pending...
#   - Installing pyasn1 (0.6.1): Downloading... 0%
#   - Installing pyasn1 (0.6.1): Downloading... 100%
#   - Installing pyasn1 (0.6.1): Installing...
#   - Installing pyasn1 (0.6.1)
#   - Installing asgiref (3.8.1): Pending...
#   - Installing cachetools (5.5.0): Pending...
#   - Installing humanfriendly (10.0): Pending...
#   - Installing oauthlib (3.2.2): Pending...
#   - Installing opentelemetry-instrumentation (0.45b0): Pending...
#   - Installing opentelemetry-util-http (0.45b0): Pending...
#   - Installing pyasn1-modules (0.4.1): Pending...
#   - Installing rsa (4.9): Pending...
#   - Installing rsa (4.9): Pending...
#   - Installing pyasn1-modules (0.4.1): Downloading... 0%
#   - Installing rsa (4.9): Pending...
#   - Installing rsa (4.9): Pending...
#   - Installing pyasn1-modules (0.4.1): Downloading... 100%
#   - Installing rsa (4.9): Pending...
#   - Installing rsa (4.9): Pending...
#   - Installing pyasn1-modules (0.4.1): Installing...
#   - Installing rsa (4.9): Pending...
#   - Installing rsa (4.9): Pending...
#   - Installing pyasn1-modules (0.4.1)
#   - Installing rsa (4.9): Pending...
#   - Installing opentelemetry-util-http (0.45b0): Pending...
#   - Installing pyasn1-modules (0.4.1)
#   - Installing rsa (4.9): Pending...
#   - Installing opentelemetry-instrumentation (0.45b0): Downloading... 0%
#   - Installing opentelemetry-util-http (0.45b0): Pending...
#   - Installing pyasn1-modules (0.4.1)
#   - Installing rsa (4.9): Pending...
#   - Installing humanfriendly (10.0): Pending...
#   - Installing oauthlib (3.2.2): Pending...
#   - Installing opentelemetry-instrumentation (0.45b0): Downloading... 0%
#   - Installing opentelemetry-util-http (0.45b0): Pending...
#   - Installing pyasn1-modules (0.4.1)
#   - Installing rsa (4.9): Pending...
#   - Installing cachetools (5.5.0): Downloading... 0%
#   - Installing humanfriendly (10.0): Pending...
#   - Installing oauthlib (3.2.2): Pending...
#   - Installing opentelemetry-instrumentation (0.45b0): Downloading... 0%
#   - Installing opentelemetry-util-http (0.45b0): Pending...
#   - Installing pyasn1-modules (0.4.1)
#   - Installing rsa (4.9): Pending...
#   - Installing oauthlib (3.2.2): Pending...
#   - Installing opentelemetry-instrumentation (0.45b0): Downloading... 0%
#   - Installing opentelemetry-util-http (0.45b0): Pending...
#   - Installing pyasn1-modules (0.4.1)
#   - Installing rsa (4.9): Pending...
#   - Installing humanfriendly (10.0): Downloading... 0%
#   - Installing oauthlib (3.2.2): Pending...
#   - Installing opentelemetry-instrumentation (0.45b0): Downloading... 0%
#   - Installing opentelemetry-util-http (0.45b0): Pending...
#   - Installing pyasn1-modules (0.4.1)
#   - Installing rsa (4.9): Pending...
#   - Installing pyasn1-modules (0.4.1)
#   - Installing rsa (4.9): Pending...
#   - Installing opentelemetry-util-http (0.45b0): Downloading... 0%
#   - Installing pyasn1-modules (0.4.1)
#   - Installing rsa (4.9): Pending...
#   - Installing cachetools (5.5.0): Downloading... 0%
#   - Installing humanfriendly (10.0): Downloading... 0%
#   - Installing oauthlib (3.2.2): Pending...
#   - Installing opentelemetry-instrumentation (0.45b0): Downloading... 0%
#   - Installing opentelemetry-util-http (0.45b0): Downloading... 0%
#   - Installing pyasn1-modules (0.4.1)
#   - Installing rsa (4.9): Pending...
#   - Installing asgiref (3.8.1): Downloading... 0%
#   - Installing cachetools (5.5.0): Downloading... 0%
#   - Installing humanfriendly (10.0): Downloading... 0%
#   - Installing oauthlib (3.2.2): Pending...
#   - Installing opentelemetry-instrumentation (0.45b0): Downloading... 0%
#   - Installing opentelemetry-util-http (0.45b0): Downloading... 0%
#   - Installing pyasn1-modules (0.4.1)
#   - Installing rsa (4.9): Pending...
#   - Installing opentelemetry-util-http (0.45b0): Downloading... 0%
#   - Installing pyasn1-modules (0.4.1)
#   - Installing rsa (4.9): Pending...
#   - Installing opentelemetry-instrumentation (0.45b0): Downloading... 100%
#   - Installing opentelemetry-util-http (0.45b0): Downloading... 0%
#   - Installing pyasn1-modules (0.4.1)
#   - Installing rsa (4.9): Pending...
#   - Installing pyasn1-modules (0.4.1)
#   - Installing rsa (4.9): Pending...
#   - Installing opentelemetry-util-http (0.45b0): Downloading... 100%
#   - Installing pyasn1-modules (0.4.1)
#   - Installing rsa (4.9): Pending...
#   - Installing opentelemetry-util-http (0.45b0): Downloading... 100%
#   - Installing pyasn1-modules (0.4.1)
#   - Installing rsa (4.9): Pending...
#   - Installing opentelemetry-instrumentation (0.45b0): Installing...
#   - Installing opentelemetry-util-http (0.45b0): Downloading... 100%
#   - Installing pyasn1-modules (0.4.1)
#   - Installing rsa (4.9): Pending...
#   - Installing humanfriendly (10.0): Downloading... 0%
#   - Installing oauthlib (3.2.2): Pending...
#   - Installing opentelemetry-instrumentation (0.45b0): Installing...
#   - Installing opentelemetry-util-http (0.45b0): Downloading... 100%
#   - Installing pyasn1-modules (0.4.1)
#   - Installing rsa (4.9): Pending...
#   - Installing cachetools (5.5.0): Downloading... 100%
#   - Installing humanfriendly (10.0): Downloading... 0%
#   - Installing oauthlib (3.2.2): Pending...
#   - Installing opentelemetry-instrumentation (0.45b0): Installing...
#   - Installing opentelemetry-util-http (0.45b0): Downloading... 100%
#   - Installing pyasn1-modules (0.4.1)
#   - Installing rsa (4.9): Pending...
#   - Installing pyasn1-modules (0.4.1)
#   - Installing rsa (4.9): Pending...
#   - Installing opentelemetry-util-http (0.45b0): Installing...
#   - Installing pyasn1-modules (0.4.1)
#   - Installing rsa (4.9): Pending...
#   - Installing cachetools (5.5.0): Downloading... 100%
#   - Installing humanfriendly (10.0): Downloading... 0%
#   - Installing oauthlib (3.2.2): Pending...
#   - Installing opentelemetry-instrumentation (0.45b0): Installing...
#   - Installing opentelemetry-util-http (0.45b0): Installing...
#   - Installing pyasn1-modules (0.4.1)
#   - Installing rsa (4.9): Pending...
#   - Installing asgiref (3.8.1): Downloading... 100%
#   - Installing cachetools (5.5.0): Downloading... 100%
#   - Installing humanfriendly (10.0): Downloading... 0%
#   - Installing oauthlib (3.2.2): Pending...
#   - Installing opentelemetry-instrumentation (0.45b0): Installing...
#   - Installing opentelemetry-util-http (0.45b0): Installing...
#   - Installing pyasn1-modules (0.4.1)
#   - Installing rsa (4.9): Pending...
#   - Installing humanfriendly (10.0): Downloading... 0%
#   - Installing oauthlib (3.2.2): Pending...
#   - Installing opentelemetry-instrumentation (0.45b0): Installing...
#   - Installing opentelemetry-util-http (0.45b0): Installing...
#   - Installing pyasn1-modules (0.4.1)
#   - Installing rsa (4.9): Pending...
#   - Installing cachetools (5.5.0): Installing...
#   - Installing humanfriendly (10.0): Downloading... 0%
#   - Installing oauthlib (3.2.2): Pending...
#   - Installing opentelemetry-instrumentation (0.45b0): Installing...
#   - Installing opentelemetry-util-http (0.45b0): Installing...
#   - Installing pyasn1-modules (0.4.1)
#   - Installing rsa (4.9): Pending...
#   - Installing cachetools (5.5.0): Installing...
#   - Installing humanfriendly (10.0): Downloading... 0%
#   - Installing oauthlib (3.2.2): Pending...
#   - Installing opentelemetry-instrumentation (0.45b0): Installing...
#   - Installing opentelemetry-util-http (0.45b0): Installing...
#   - Installing pyasn1-modules (0.4.1)
#   - Installing rsa (4.9): Pending...
#   - Installing asgiref (3.8.1): Installing...
#   - Installing cachetools (5.5.0): Installing...
#   - Installing humanfriendly (10.0): Downloading... 0%
#   - Installing oauthlib (3.2.2): Pending...
#   - Installing opentelemetry-instrumentation (0.45b0): Installing...
#   - Installing opentelemetry-util-http (0.45b0): Installing...
#   - Installing pyasn1-modules (0.4.1)
#   - Installing rsa (4.9): Pending...
#   - Installing pyasn1-modules (0.4.1)
#   - Installing rsa (4.9): Pending...
#   - Installing opentelemetry-util-http (0.45b0)
#   - Installing pyasn1-modules (0.4.1)
#   - Installing rsa (4.9): Pending...
#   - Installing humanfriendly (10.0): Downloading... 0%
#   - Installing oauthlib (3.2.2): Pending...
#   - Installing opentelemetry-instrumentation (0.45b0): Installing...
#   - Installing opentelemetry-util-http (0.45b0)
#   - Installing pyasn1-modules (0.4.1)
#   - Installing rsa (4.9): Pending...
#   - Installing cachetools (5.5.0)
#   - Installing humanfriendly (10.0): Downloading... 0%
#   - Installing oauthlib (3.2.2): Pending...
#   - Installing opentelemetry-instrumentation (0.45b0): Installing...
#   - Installing opentelemetry-util-http (0.45b0)
#   - Installing pyasn1-modules (0.4.1)
#   - Installing rsa (4.9): Pending...
#   - Installing rsa (4.9): Downloading... 0%
#   - Installing oauthlib (3.2.2): Pending...
#   - Installing opentelemetry-instrumentation (0.45b0): Installing...
#   - Installing opentelemetry-util-http (0.45b0)
#   - Installing pyasn1-modules (0.4.1)
#   - Installing rsa (4.9): Downloading... 0%
#   - Installing humanfriendly (10.0): Downloading... 100%
#   - Installing oauthlib (3.2.2): Pending...
#   - Installing opentelemetry-instrumentation (0.45b0): Installing...
#   - Installing opentelemetry-util-http (0.45b0)
#   - Installing pyasn1-modules (0.4.1)
#   - Installing rsa (4.9): Downloading... 0%
#   - Installing oauthlib (3.2.2): Pending...
#   - Installing opentelemetry-instrumentation (0.45b0): Installing...
#   - Installing opentelemetry-util-http (0.45b0)
#   - Installing pyasn1-modules (0.4.1)
#   - Installing rsa (4.9): Downloading... 0%
#   - Installing humanfriendly (10.0): Installing...
#   - Installing oauthlib (3.2.2): Pending...
#   - Installing opentelemetry-instrumentation (0.45b0): Installing...
#   - Installing opentelemetry-util-http (0.45b0)
#   - Installing pyasn1-modules (0.4.1)
#   - Installing rsa (4.9): Downloading... 0%
#   - Installing cachetools (5.5.0)
#   - Installing humanfriendly (10.0): Installing...
#   - Installing oauthlib (3.2.2): Pending...
#   - Installing opentelemetry-instrumentation (0.45b0): Installing...
#   - Installing opentelemetry-util-http (0.45b0)
#   - Installing pyasn1-modules (0.4.1)
#   - Installing rsa (4.9): Downloading... 0%
#   - Installing asgiref (3.8.1)
#   - Installing cachetools (5.5.0)
#   - Installing humanfriendly (10.0): Installing...
#   - Installing oauthlib (3.2.2): Pending...
#   - Installing opentelemetry-instrumentation (0.45b0): Installing...
#   - Installing opentelemetry-util-http (0.45b0)
#   - Installing pyasn1-modules (0.4.1)
#   - Installing rsa (4.9): Downloading... 0%
#   - Installing opentelemetry-util-http (0.45b0)
#   - Installing pyasn1-modules (0.4.1)
#   - Installing rsa (4.9): Downloading... 0%
#   - Installing opentelemetry-instrumentation (0.45b0)
#   - Installing opentelemetry-util-http (0.45b0)
#   - Installing pyasn1-modules (0.4.1)
#   - Installing rsa (4.9): Downloading... 0%
#   - Installing opentelemetry-instrumentation (0.45b0)
#   - Installing opentelemetry-util-http (0.45b0)
#   - Installing pyasn1-modules (0.4.1)
#   - Installing rsa (4.9): Downloading... 0%
#   - Installing oauthlib (3.2.2): Downloading... 0%
#   - Installing opentelemetry-instrumentation (0.45b0)
#   - Installing opentelemetry-util-http (0.45b0)
#   - Installing pyasn1-modules (0.4.1)
#   - Installing rsa (4.9): Downloading... 0%
#   - Installing rsa (4.9): Downloading... 100%
#   - Installing rsa (4.9): Installing...
#   - Installing opentelemetry-instrumentation (0.45b0)
#   - Installing opentelemetry-util-http (0.45b0)
#   - Installing pyasn1-modules (0.4.1)
#   - Installing rsa (4.9): Installing...
#   - Installing oauthlib (3.2.2): Downloading... 100%
#   - Installing opentelemetry-instrumentation (0.45b0)
#   - Installing opentelemetry-util-http (0.45b0)
#   - Installing pyasn1-modules (0.4.1)
#   - Installing rsa (4.9): Installing...
#   - Installing opentelemetry-instrumentation (0.45b0)
#   - Installing opentelemetry-util-http (0.45b0)
#   - Installing pyasn1-modules (0.4.1)
#   - Installing rsa (4.9): Installing...
#   - Installing oauthlib (3.2.2): Installing...
#   - Installing opentelemetry-instrumentation (0.45b0)
#   - Installing opentelemetry-util-http (0.45b0)
#   - Installing pyasn1-modules (0.4.1)
#   - Installing rsa (4.9): Installing...
#   - Installing oauthlib (3.2.2): Installing...
#   - Installing opentelemetry-instrumentation (0.45b0)
#   - Installing opentelemetry-util-http (0.45b0)
#   - Installing pyasn1-modules (0.4.1)
#   - Installing rsa (4.9): Installing...
#   - Installing humanfriendly (10.0)
#   - Installing oauthlib (3.2.2): Installing...
#   - Installing opentelemetry-instrumentation (0.45b0)
#   - Installing opentelemetry-util-http (0.45b0)
#   - Installing pyasn1-modules (0.4.1)
#   - Installing rsa (4.9): Installing...
#   - Installing rsa (4.9)
#   - Installing opentelemetry-instrumentation (0.45b0)
#   - Installing opentelemetry-util-http (0.45b0)
#   - Installing pyasn1-modules (0.4.1)
#   - Installing rsa (4.9)
#   - Installing oauthlib (3.2.2)
#   - Installing opentelemetry-instrumentation (0.45b0)
#   - Installing opentelemetry-util-http (0.45b0)
#   - Installing pyasn1-modules (0.4.1)
#   - Installing rsa (4.9)
#   - Installing backoff (2.2.1): Pending...
#   - Installing coloredlogs (15.0.1): Pending...
#   - Installing durationpy (0.9): Pending...
#   - Installing flatbuffers (24.3.25): Pending...
#   - Installing google-auth (2.35.0): Pending...
#   - Installing httptools (0.6.1): Pending...
#   - Installing monotonic (1.6): Pending...
#   - Installing opentelemetry-instrumentation-asgi (0.45b0): Pending...
#   - Installing pyproject-hooks (1.2.0): Pending...
#   - Installing requests-oauthlib (2.0.0): Pending...
#   - Installing starlette (0.38.6): Pending...
#   - Installing uvloop (0.20.0): Pending...
#   - Installing watchfiles (0.24.0): Pending...
#   - Installing websockets (13.1): Pending...
#   - Installing google-auth (2.35.0): Pending...
#   - Installing httptools (0.6.1): Pending...
#   - Installing monotonic (1.6): Pending...
#   - Installing opentelemetry-instrumentation-asgi (0.45b0): Pending...
#   - Installing pyproject-hooks (1.2.0): Pending...
#   - Installing requests-oauthlib (2.0.0): Pending...
#   - Installing starlette (0.38.6): Pending...
#   - Installing uvloop (0.20.0): Pending...
#   - Installing watchfiles (0.24.0): Pending...
#   - Installing websockets (13.1): Pending...
#   - Installing flatbuffers (24.3.25): Downloading... 0%
#   - Installing google-auth (2.35.0): Pending...
#   - Installing httptools (0.6.1): Pending...
#   - Installing monotonic (1.6): Pending...
#   - Installing opentelemetry-instrumentation-asgi (0.45b0): Pending...
#   - Installing pyproject-hooks (1.2.0): Pending...
#   - Installing requests-oauthlib (2.0.0): Pending...
#   - Installing starlette (0.38.6): Pending...
#   - Installing uvloop (0.20.0): Pending...
#   - Installing watchfiles (0.24.0): Pending...
#   - Installing websockets (13.1): Pending...
#   - Installing monotonic (1.6): Pending...
#   - Installing opentelemetry-instrumentation-asgi (0.45b0): Pending...
#   - Installing pyproject-hooks (1.2.0): Pending...
#   - Installing requests-oauthlib (2.0.0): Pending...
#   - Installing starlette (0.38.6): Pending...
#   - Installing uvloop (0.20.0): Pending...
#   - Installing watchfiles (0.24.0): Pending...
#   - Installing websockets (13.1): Pending...
#   - Installing httptools (0.6.1): Installing...
#   - Installing monotonic (1.6): Pending...
#   - Installing opentelemetry-instrumentation-asgi (0.45b0): Pending...
#   - Installing pyproject-hooks (1.2.0): Pending...
#   - Installing requests-oauthlib (2.0.0): Pending...
#   - Installing starlette (0.38.6): Pending...
#   - Installing uvloop (0.20.0): Pending...
#   - Installing watchfiles (0.24.0): Pending...
#   - Installing websockets (13.1): Pending...
#   - Installing pyproject-hooks (1.2.0): Pending...
#   - Installing requests-oauthlib (2.0.0): Pending...
#   - Installing starlette (0.38.6): Pending...
#   - Installing uvloop (0.20.0): Pending...
#   - Installing watchfiles (0.24.0): Pending...
#   - Installing websockets (13.1): Pending...
#   - Installing opentelemetry-instrumentation-asgi (0.45b0): Downloading... 0%
#   - Installing pyproject-hooks (1.2.0): Pending...
#   - Installing requests-oauthlib (2.0.0): Pending...
#   - Installing starlette (0.38.6): Pending...
#   - Installing uvloop (0.20.0): Pending...
#   - Installing watchfiles (0.24.0): Pending...
#   - Installing websockets (13.1): Pending...
#   - Installing requests-oauthlib (2.0.0): Pending...
#   - Installing starlette (0.38.6): Pending...
#   - Installing uvloop (0.20.0): Pending...
#   - Installing watchfiles (0.24.0): Pending...
#   - Installing websockets (13.1): Pending...
#   - Installing pyproject-hooks (1.2.0): Downloading... 0%
#   - Installing requests-oauthlib (2.0.0): Pending...
#   - Installing starlette (0.38.6): Pending...
#   - Installing uvloop (0.20.0): Pending...
#   - Installing watchfiles (0.24.0): Pending...
#   - Installing websockets (13.1): Pending...
#   - Installing flatbuffers (24.3.25): Downloading... 0%
#   - Installing google-auth (2.35.0): Pending...
#   - Installing httptools (0.6.1): Installing...
#   - Installing monotonic (1.6): Pending...
#   - Installing opentelemetry-instrumentation-asgi (0.45b0): Downloading... 0%
#   - Installing pyproject-hooks (1.2.0): Downloading... 0%
#   - Installing requests-oauthlib (2.0.0): Pending...
#   - Installing starlette (0.38.6): Pending...
#   - Installing uvloop (0.20.0): Pending...
#   - Installing watchfiles (0.24.0): Pending...
#   - Installing websockets (13.1): Pending...
#   - Installing durationpy (0.9): Downloading... 0%
#   - Installing flatbuffers (24.3.25): Downloading... 0%
#   - Installing google-auth (2.35.0): Pending...
#   - Installing httptools (0.6.1): Installing...
#   - Installing monotonic (1.6): Pending...
#   - Installing opentelemetry-instrumentation-asgi (0.45b0): Downloading... 0%
#   - Installing pyproject-hooks (1.2.0): Downloading... 0%
#   - Installing requests-oauthlib (2.0.0): Pending...
#   - Installing starlette (0.38.6): Pending...
#   - Installing uvloop (0.20.0): Pending...
#   - Installing watchfiles (0.24.0): Pending...
#   - Installing websockets (13.1): Pending...
#   - Installing uvloop (0.20.0): Pending...
#   - Installing watchfiles (0.24.0): Pending...
#   - Installing websockets (13.1): Pending...
#   - Installing starlette (0.38.6): Downloading... 0%
#   - Installing uvloop (0.20.0): Pending...
#   - Installing watchfiles (0.24.0): Pending...
#   - Installing websockets (13.1): Pending...
#   - Installing google-auth (2.35.0): Pending...
#   - Installing httptools (0.6.1): Installing...
#   - Installing monotonic (1.6): Pending...
#   - Installing opentelemetry-instrumentation-asgi (0.45b0): Downloading... 0%
#   - Installing pyproject-hooks (1.2.0): Downloading... 0%
#   - Installing requests-oauthlib (2.0.0): Pending...
#   - Installing starlette (0.38.6): Downloading... 0%
#   - Installing uvloop (0.20.0): Pending...
#   - Installing watchfiles (0.24.0): Pending...
#   - Installing websockets (13.1): Pending...
#   - Installing flatbuffers (24.3.25): Downloading... 100%
#   - Installing google-auth (2.35.0): Pending...
#   - Installing httptools (0.6.1): Installing...
#   - Installing monotonic (1.6): Pending...
#   - Installing opentelemetry-instrumentation-asgi (0.45b0): Downloading... 0%
#   - Installing pyproject-hooks (1.2.0): Downloading... 0%
#   - Installing requests-oauthlib (2.0.0): Pending...
#   - Installing starlette (0.38.6): Downloading... 0%
#   - Installing uvloop (0.20.0): Pending...
#   - Installing watchfiles (0.24.0): Pending...
#   - Installing websockets (13.1): Pending...
#   - Installing httptools (0.6.1): Installing...
#   - Installing monotonic (1.6): Pending...
#   - Installing opentelemetry-instrumentation-asgi (0.45b0): Downloading... 0%
#   - Installing pyproject-hooks (1.2.0): Downloading... 0%
#   - Installing requests-oauthlib (2.0.0): Pending...
#   - Installing starlette (0.38.6): Downloading... 0%
#   - Installing uvloop (0.20.0): Pending...
#   - Installing watchfiles (0.24.0): Pending...
#   - Installing websockets (13.1): Pending...
#   - Installing google-auth (2.35.0): Downloading... 0%
#   - Installing httptools (0.6.1): Installing...
#   - Installing monotonic (1.6): Pending...
#   - Installing opentelemetry-instrumentation-asgi (0.45b0): Downloading... 0%
#   - Installing pyproject-hooks (1.2.0): Downloading... 0%
#   - Installing requests-oauthlib (2.0.0): Pending...
#   - Installing starlette (0.38.6): Downloading... 0%
#   - Installing uvloop (0.20.0): Pending...
#   - Installing watchfiles (0.24.0): Pending...
#   - Installing websockets (13.1): Pending...
#   - Installing flatbuffers (24.3.25): Downloading... 100%
#   - Installing google-auth (2.35.0): Downloading... 0%
#   - Installing httptools (0.6.1): Installing...
#   - Installing monotonic (1.6): Pending...
#   - Installing opentelemetry-instrumentation-asgi (0.45b0): Downloading... 0%
#   - Installing pyproject-hooks (1.2.0): Downloading... 0%
#   - Installing requests-oauthlib (2.0.0): Pending...
#   - Installing starlette (0.38.6): Downloading... 0%
#   - Installing uvloop (0.20.0): Pending...
#   - Installing watchfiles (0.24.0): Pending...
#   - Installing websockets (13.1): Pending...
#   - Installing durationpy (0.9): Downloading... 100%
#   - Installing flatbuffers (24.3.25): Downloading... 100%
#   - Installing google-auth (2.35.0): Downloading... 0%
#   - Installing httptools (0.6.1): Installing...
#   - Installing monotonic (1.6): Pending...
#   - Installing opentelemetry-instrumentation-asgi (0.45b0): Downloading... 0%
#   - Installing pyproject-hooks (1.2.0): Downloading... 0%
#   - Installing requests-oauthlib (2.0.0): Pending...
#   - Installing starlette (0.38.6): Downloading... 0%
#   - Installing uvloop (0.20.0): Pending...
#   - Installing watchfiles (0.24.0): Pending...
#   - Installing websockets (13.1): Pending...
#   - Installing requests-oauthlib (2.0.0): Pending...
#   - Installing starlette (0.38.6): Downloading... 0%
#   - Installing uvloop (0.20.0): Pending...
#   - Installing watchfiles (0.24.0): Pending...
#   - Installing websockets (13.1): Pending...
#   - Installing pyproject-hooks (1.2.0): Downloading... 100%
#   - Installing requests-oauthlib (2.0.0): Pending...
#   - Installing starlette (0.38.6): Downloading... 0%
#   - Installing uvloop (0.20.0): Pending...
#   - Installing watchfiles (0.24.0): Pending...
#   - Installing websockets (13.1): Pending...
#   - Installing pyproject-hooks (1.2.0): Downloading... 100%
#   - Installing requests-oauthlib (2.0.0): Pending...
#   - Installing starlette (0.38.6): Downloading... 0%
#   - Installing uvloop (0.20.0): Pending...
#   - Installing watchfiles (0.24.0): Pending...
#   - Installing websockets (13.1): Pending...
#   - Installing opentelemetry-instrumentation-asgi (0.45b0): Downloading... 100%
#   - Installing pyproject-hooks (1.2.0): Downloading... 100%
#   - Installing requests-oauthlib (2.0.0): Pending...
#   - Installing starlette (0.38.6): Downloading... 0%
#   - Installing uvloop (0.20.0): Pending...
#   - Installing watchfiles (0.24.0): Pending...
#   - Installing websockets (13.1): Pending...
#   - Installing google-auth (2.35.0): Downloading... 0%
#   - Installing httptools (0.6.1): Installing...
#   - Installing monotonic (1.6): Pending...
#   - Installing opentelemetry-instrumentation-asgi (0.45b0): Downloading... 100%
#   - Installing pyproject-hooks (1.2.0): Downloading... 100%
#   - Installing requests-oauthlib (2.0.0): Pending...
#   - Installing starlette (0.38.6): Downloading... 0%
#   - Installing uvloop (0.20.0): Pending...
#   - Installing watchfiles (0.24.0): Pending...
#   - Installing websockets (13.1): Pending...
#   - Installing flatbuffers (24.3.25): Installing...
#   - Installing google-auth (2.35.0): Downloading... 0%
#   - Installing httptools (0.6.1): Installing...
#   - Installing monotonic (1.6): Pending...
#   - Installing opentelemetry-instrumentation-asgi (0.45b0): Downloading... 100%
#   - Installing pyproject-hooks (1.2.0): Downloading... 100%
#   - Installing requests-oauthlib (2.0.0): Pending...
#   - Installing starlette (0.38.6): Downloading... 0%
#   - Installing uvloop (0.20.0): Pending...
#   - Installing watchfiles (0.24.0): Pending...
#   - Installing websockets (13.1): Pending...
#   - Installing flatbuffers (24.3.25): Installing...
#   - Installing google-auth (2.35.0): Downloading... 0%
#   - Installing httptools (0.6.1): Installing...
#   - Installing monotonic (1.6): Pending...
#   - Installing opentelemetry-instrumentation-asgi (0.45b0): Downloading... 100%
#   - Installing pyproject-hooks (1.2.0): Downloading... 100%
#   - Installing requests-oauthlib (2.0.0): Pending...
#   - Installing starlette (0.38.6): Downloading... 0%
#   - Installing uvloop (0.20.0): Pending...
#   - Installing watchfiles (0.24.0): Pending...
#   - Installing websockets (13.1): Pending...
#   - Installing durationpy (0.9): Installing...
#   - Installing flatbuffers (24.3.25): Installing...
#   - Installing google-auth (2.35.0): Downloading... 0%
#   - Installing httptools (0.6.1): Installing...
#   - Installing monotonic (1.6): Pending...
#   - Installing opentelemetry-instrumentation-asgi (0.45b0): Downloading... 100%
#   - Installing pyproject-hooks (1.2.0): Downloading... 100%
#   - Installing requests-oauthlib (2.0.0): Pending...
#   - Installing starlette (0.38.6): Downloading... 0%
#   - Installing uvloop (0.20.0): Pending...
#   - Installing watchfiles (0.24.0): Pending...
#   - Installing websockets (13.1): Pending...
#   - Installing requests-oauthlib (2.0.0): Pending...
#   - Installing starlette (0.38.6): Downloading... 0%
#   - Installing uvloop (0.20.0): Pending...
#   - Installing watchfiles (0.24.0): Pending...
#   - Installing websockets (13.1): Pending...
#   - Installing pyproject-hooks (1.2.0): Installing...
#   - Installing requests-oauthlib (2.0.0): Pending...
#   - Installing starlette (0.38.6): Downloading... 0%
#   - Installing uvloop (0.20.0): Pending...
#   - Installing watchfiles (0.24.0): Pending...
#   - Installing websockets (13.1): Pending...
#   - Installing pyproject-hooks (1.2.0): Installing...
#   - Installing requests-oauthlib (2.0.0): Pending...
#   - Installing starlette (0.38.6): Downloading... 0%
#   - Installing uvloop (0.20.0): Pending...
#   - Installing watchfiles (0.24.0): Pending...
#   - Installing websockets (13.1): Pending...
#   - Installing opentelemetry-instrumentation-asgi (0.45b0): Installing...
#   - Installing pyproject-hooks (1.2.0): Installing...
#   - Installing requests-oauthlib (2.0.0): Pending...
#   - Installing starlette (0.38.6): Downloading... 0%
#   - Installing uvloop (0.20.0): Pending...
#   - Installing watchfiles (0.24.0): Pending...
#   - Installing websockets (13.1): Pending...
#   - Installing monotonic (1.6): Pending...
#   - Installing opentelemetry-instrumentation-asgi (0.45b0): Installing...
#   - Installing pyproject-hooks (1.2.0): Installing...
#   - Installing requests-oauthlib (2.0.0): Pending...
#   - Installing starlette (0.38.6): Downloading... 0%
#   - Installing uvloop (0.20.0): Pending...
#   - Installing watchfiles (0.24.0): Pending...
#   - Installing websockets (13.1): Pending...
#   - Installing httptools (0.6.1)
#   - Installing monotonic (1.6): Pending...
#   - Installing opentelemetry-instrumentation-asgi (0.45b0): Installing...
#   - Installing pyproject-hooks (1.2.0): Installing...
#   - Installing requests-oauthlib (2.0.0): Pending...
#   - Installing starlette (0.38.6): Downloading... 0%
#   - Installing uvloop (0.20.0): Pending...
#   - Installing watchfiles (0.24.0): Pending...
#   - Installing websockets (13.1): Pending...
#   - Installing flatbuffers (24.3.25): Installing...
#   - Installing google-auth (2.35.0): Downloading... 0%
#   - Installing httptools (0.6.1)
#   - Installing monotonic (1.6): Pending...
#   - Installing opentelemetry-instrumentation-asgi (0.45b0): Installing...
#   - Installing pyproject-hooks (1.2.0): Installing...
#   - Installing requests-oauthlib (2.0.0): Pending...
#   - Installing starlette (0.38.6): Downloading... 0%
#   - Installing uvloop (0.20.0): Pending...
#   - Installing watchfiles (0.24.0): Pending...
#   - Installing websockets (13.1): Pending...
#   - Installing durationpy (0.9)
#   - Installing flatbuffers (24.3.25): Installing...
#   - Installing google-auth (2.35.0): Downloading... 0%
#   - Installing httptools (0.6.1)
#   - Installing monotonic (1.6): Pending...
#   - Installing opentelemetry-instrumentation-asgi (0.45b0): Installing...
#   - Installing pyproject-hooks (1.2.0): Installing...
#   - Installing requests-oauthlib (2.0.0): Pending...
#   - Installing starlette (0.38.6): Downloading... 0%
#   - Installing uvloop (0.20.0): Pending...
#   - Installing watchfiles (0.24.0): Pending...
#   - Installing websockets (13.1): Pending...
#   - Installing pyproject-hooks (1.2.0): Installing...
#   - Installing requests-oauthlib (2.0.0): Pending...
#   - Installing starlette (0.38.6): Downloading... 0%
#   - Installing uvloop (0.20.0): Pending...
#   - Installing watchfiles (0.24.0): Pending...
#   - Installing websockets (13.1): Pending...
#   - Installing opentelemetry-instrumentation-asgi (0.45b0)
#   - Installing pyproject-hooks (1.2.0): Installing...
#   - Installing requests-oauthlib (2.0.0): Pending...
#   - Installing starlette (0.38.6): Downloading... 0%
#   - Installing uvloop (0.20.0): Pending...
#   - Installing watchfiles (0.24.0): Pending...
#   - Installing websockets (13.1): Pending...
#   - Installing uvloop (0.20.0): Pending...
#   - Installing watchfiles (0.24.0): Pending...
#   - Installing websockets (13.1): Pending...
#   - Installing starlette (0.38.6): Downloading... 100%
#   - Installing uvloop (0.20.0): Pending...
#   - Installing watchfiles (0.24.0): Pending...
#   - Installing websockets (13.1): Pending...
#   - Installing requests-oauthlib (2.0.0): Pending...
#   - Installing starlette (0.38.6): Downloading... 100%
#   - Installing uvloop (0.20.0): Pending...
#   - Installing watchfiles (0.24.0): Pending...
#   - Installing websockets (13.1): Pending...
#   - Installing pyproject-hooks (1.2.0)
#   - Installing requests-oauthlib (2.0.0): Pending...
#   - Installing starlette (0.38.6): Downloading... 100%
#   - Installing uvloop (0.20.0): Pending...
#   - Installing watchfiles (0.24.0): Pending...
#   - Installing websockets (13.1): Pending...
#   - Installing google-auth (2.35.0): Downloading... 0%
#   - Installing httptools (0.6.1)
#   - Installing monotonic (1.6): Pending...
#   - Installing opentelemetry-instrumentation-asgi (0.45b0)
#   - Installing pyproject-hooks (1.2.0)
#   - Installing requests-oauthlib (2.0.0): Pending...
#   - Installing starlette (0.38.6): Downloading... 100%
#   - Installing uvloop (0.20.0): Pending...
#   - Installing watchfiles (0.24.0): Pending...
#   - Installing websockets (13.1): Pending...
#   - Installing flatbuffers (24.3.25)
#   - Installing google-auth (2.35.0): Downloading... 0%
#   - Installing httptools (0.6.1)
#   - Installing monotonic (1.6): Pending...
#   - Installing opentelemetry-instrumentation-asgi (0.45b0)
#   - Installing pyproject-hooks (1.2.0)
#   - Installing requests-oauthlib (2.0.0): Pending...
#   - Installing starlette (0.38.6): Downloading... 100%
#   - Installing uvloop (0.20.0): Pending...
#   - Installing watchfiles (0.24.0): Pending...
#   - Installing websockets (13.1): Pending...
#   - Installing uvloop (0.20.0): Pending...
#   - Installing watchfiles (0.24.0): Pending...
#   - Installing websockets (13.1): Pending...
#   - Installing starlette (0.38.6): Installing...
#   - Installing uvloop (0.20.0): Pending...
#   - Installing watchfiles (0.24.0): Pending...
#   - Installing websockets (13.1): Pending...
#   - Installing websockets (13.1): Downloading... 0%
#   - Installing websockets (13.1): Downloading... 0%
#   - Installing watchfiles (0.24.0): Downloading... 0%
#   - Installing websockets (13.1): Downloading... 0%
#   - Installing httptools (0.6.1)
#   - Installing monotonic (1.6): Pending...
#   - Installing opentelemetry-instrumentation-asgi (0.45b0)
#   - Installing pyproject-hooks (1.2.0)
#   - Installing requests-oauthlib (2.0.0): Pending...
#   - Installing starlette (0.38.6): Installing...
#   - Installing uvloop (0.20.0): Pending...
#   - Installing watchfiles (0.24.0): Downloading... 0%
#   - Installing websockets (13.1): Downloading... 0%
#   - Installing google-auth (2.35.0): Downloading... 100%
#   - Installing httptools (0.6.1)
#   - Installing monotonic (1.6): Pending...
#   - Installing opentelemetry-instrumentation-asgi (0.45b0)
#   - Installing pyproject-hooks (1.2.0)
#   - Installing requests-oauthlib (2.0.0): Pending...
#   - Installing starlette (0.38.6): Installing...
#   - Installing uvloop (0.20.0): Pending...
#   - Installing watchfiles (0.24.0): Downloading... 0%
#   - Installing websockets (13.1): Downloading... 0%
#   - Installing httptools (0.6.1)
#   - Installing monotonic (1.6): Pending...
#   - Installing opentelemetry-instrumentation-asgi (0.45b0)
#   - Installing pyproject-hooks (1.2.0)
#   - Installing requests-oauthlib (2.0.0): Pending...
#   - Installing starlette (0.38.6): Installing...
#   - Installing uvloop (0.20.0): Pending...
#   - Installing watchfiles (0.24.0): Downloading... 0%
#   - Installing websockets (13.1): Downloading... 0%
#   - Installing google-auth (2.35.0): Installing...
#   - Installing httptools (0.6.1)
#   - Installing monotonic (1.6): Pending...
#   - Installing opentelemetry-instrumentation-asgi (0.45b0)
#   - Installing pyproject-hooks (1.2.0)
#   - Installing requests-oauthlib (2.0.0): Pending...
#   - Installing starlette (0.38.6): Installing...
#   - Installing uvloop (0.20.0): Pending...
#   - Installing watchfiles (0.24.0): Downloading... 0%
#   - Installing websockets (13.1): Downloading... 0%
#   - Installing uvloop (0.20.0): Pending...
#   - Installing watchfiles (0.24.0): Downloading... 0%
#   - Installing websockets (13.1): Downloading... 0%
#   - Installing starlette (0.38.6)
#   - Installing uvloop (0.20.0): Pending...
#   - Installing watchfiles (0.24.0): Downloading... 0%
#   - Installing websockets (13.1): Downloading... 0%
#   - Installing watchfiles (0.24.0): Downloading... 0%
#   - Installing websockets (13.1): Downloading... 0%
#   - Installing uvloop (0.20.0): Downloading... 0%
#   - Installing watchfiles (0.24.0): Downloading... 0%
#   - Installing websockets (13.1): Downloading... 0%
#   - Installing starlette (0.38.6)
#   - Installing uvloop (0.20.0): Downloading... 0%
#   - Installing watchfiles (0.24.0): Downloading... 0%
#   - Installing websockets (13.1): Downloading... 0%
#   - Installing requests-oauthlib (2.0.0): Downloading... 0%
#   - Installing starlette (0.38.6)
#   - Installing uvloop (0.20.0): Downloading... 0%
#   - Installing watchfiles (0.24.0): Downloading... 0%
#   - Installing websockets (13.1): Downloading... 0%
#   - Installing httptools (0.6.1)
#   - Installing monotonic (1.6): Pending...
#   - Installing opentelemetry-instrumentation-asgi (0.45b0)
#   - Installing pyproject-hooks (1.2.0)
#   - Installing requests-oauthlib (2.0.0): Downloading... 0%
#   - Installing starlette (0.38.6)
#   - Installing uvloop (0.20.0): Downloading... 0%
#   - Installing watchfiles (0.24.0): Downloading... 0%
#   - Installing websockets (13.1): Downloading... 0%
#   - Installing google-auth (2.35.0)
#   - Installing httptools (0.6.1)
#   - Installing monotonic (1.6): Pending...
#   - Installing opentelemetry-instrumentation-asgi (0.45b0)
#   - Installing pyproject-hooks (1.2.0)
#   - Installing requests-oauthlib (2.0.0): Downloading... 0%
#   - Installing starlette (0.38.6)
#   - Installing uvloop (0.20.0): Downloading... 0%
#   - Installing watchfiles (0.24.0): Downloading... 0%
#   - Installing websockets (13.1): Downloading... 0%
#   - Installing opentelemetry-instrumentation-asgi (0.45b0)
#   - Installing pyproject-hooks (1.2.0)
#   - Installing requests-oauthlib (2.0.0): Downloading... 0%
#   - Installing starlette (0.38.6)
#   - Installing uvloop (0.20.0): Downloading... 0%
#   - Installing watchfiles (0.24.0): Downloading... 0%
#   - Installing websockets (13.1): Downloading... 0%
#   - Installing monotonic (1.6): Downloading... 0%
#   - Installing opentelemetry-instrumentation-asgi (0.45b0)
#   - Installing pyproject-hooks (1.2.0)
#   - Installing requests-oauthlib (2.0.0): Downloading... 0%
#   - Installing starlette (0.38.6)
#   - Installing uvloop (0.20.0): Downloading... 0%
#   - Installing watchfiles (0.24.0): Downloading... 0%
#   - Installing websockets (13.1): Downloading... 0%
#   - Installing opentelemetry-instrumentation-asgi (0.45b0)
#   - Installing pyproject-hooks (1.2.0)
#   - Installing requests-oauthlib (2.0.0): Downloading... 0%
#   - Installing starlette (0.38.6)
#   - Installing uvloop (0.20.0): Downloading... 0%
#   - Installing watchfiles (0.24.0): Downloading... 0%
#   - Installing websockets (13.1): Downloading... 0%
#   - Installing monotonic (1.6): Downloading... 100%
#   - Installing opentelemetry-instrumentation-asgi (0.45b0)
#   - Installing pyproject-hooks (1.2.0)
#   - Installing requests-oauthlib (2.0.0): Downloading... 0%
#   - Installing starlette (0.38.6)
#   - Installing uvloop (0.20.0): Downloading... 0%
#   - Installing watchfiles (0.24.0): Downloading... 0%
#   - Installing websockets (13.1): Downloading... 0%
#   - Installing starlette (0.38.6)
#   - Installing uvloop (0.20.0): Downloading... 0%
#   - Installing watchfiles (0.24.0): Downloading... 0%
#   - Installing websockets (13.1): Downloading... 0%
#   - Installing requests-oauthlib (2.0.0): Downloading... 100%
#   - Installing starlette (0.38.6)
#   - Installing uvloop (0.20.0): Downloading... 0%
#   - Installing watchfiles (0.24.0): Downloading... 0%
#   - Installing websockets (13.1): Downloading... 0%
#   - Installing opentelemetry-instrumentation-asgi (0.45b0)
#   - Installing pyproject-hooks (1.2.0)
#   - Installing requests-oauthlib (2.0.0): Downloading... 100%
#   - Installing starlette (0.38.6)
#   - Installing uvloop (0.20.0): Downloading... 0%
#   - Installing watchfiles (0.24.0): Downloading... 0%
#   - Installing websockets (13.1): Downloading... 0%
#   - Installing monotonic (1.6): Installing...
#   - Installing opentelemetry-instrumentation-asgi (0.45b0)
#   - Installing pyproject-hooks (1.2.0)
#   - Installing requests-oauthlib (2.0.0): Downloading... 100%
#   - Installing starlette (0.38.6)
#   - Installing uvloop (0.20.0): Downloading... 0%
#   - Installing watchfiles (0.24.0): Downloading... 0%
#   - Installing websockets (13.1): Downloading... 0%
#   - Installing starlette (0.38.6)
#   - Installing uvloop (0.20.0): Downloading... 0%
#   - Installing watchfiles (0.24.0): Downloading... 0%
#   - Installing websockets (13.1): Downloading... 0%
#   - Installing requests-oauthlib (2.0.0): Installing...
#   - Installing starlette (0.38.6)
#   - Installing uvloop (0.20.0): Downloading... 0%
#   - Installing watchfiles (0.24.0): Downloading... 0%
#   - Installing websockets (13.1): Downloading... 0%
#   - Installing opentelemetry-instrumentation-asgi (0.45b0)
#   - Installing pyproject-hooks (1.2.0)
#   - Installing requests-oauthlib (2.0.0): Installing...
#   - Installing starlette (0.38.6)
#   - Installing uvloop (0.20.0): Downloading... 0%
#   - Installing watchfiles (0.24.0): Downloading... 0%
#   - Installing websockets (13.1): Downloading... 0%
#   - Installing monotonic (1.6)
#   - Installing opentelemetry-instrumentation-asgi (0.45b0)
#   - Installing pyproject-hooks (1.2.0)
#   - Installing requests-oauthlib (2.0.0): Installing...
#   - Installing starlette (0.38.6)
#   - Installing uvloop (0.20.0): Downloading... 0%
#   - Installing watchfiles (0.24.0): Downloading... 0%
#   - Installing websockets (13.1): Downloading... 0%
#   - Installing starlette (0.38.6)
#   - Installing uvloop (0.20.0): Downloading... 0%
#   - Installing watchfiles (0.24.0): Downloading... 0%
#   - Installing websockets (13.1): Downloading... 0%
#   - Installing requests-oauthlib (2.0.0)
#   - Installing starlette (0.38.6)
#   - Installing uvloop (0.20.0): Downloading... 0%
#   - Installing watchfiles (0.24.0): Downloading... 0%
#   - Installing websockets (13.1): Downloading... 0%
#   - Installing coloredlogs (15.0.1): Pending...
#   - Installing durationpy (0.9)
#   - Installing flatbuffers (24.3.25)
#   - Installing google-auth (2.35.0)
#   - Installing httptools (0.6.1)
#   - Installing monotonic (1.6)
#   - Installing opentelemetry-instrumentation-asgi (0.45b0)
#   - Installing pyproject-hooks (1.2.0)
#   - Installing requests-oauthlib (2.0.0)
#   - Installing starlette (0.38.6)
#   - Installing uvloop (0.20.0): Downloading... 0%
#   - Installing watchfiles (0.24.0): Downloading... 0%
#   - Installing websockets (13.1): Downloading... 0%
#   - Installing backoff (2.2.1): Downloading... 0%
#   - Installing coloredlogs (15.0.1): Pending...
#   - Installing durationpy (0.9)
#   - Installing flatbuffers (24.3.25)
#   - Installing google-auth (2.35.0)
#   - Installing httptools (0.6.1)
#   - Installing monotonic (1.6)
#   - Installing opentelemetry-instrumentation-asgi (0.45b0)
#   - Installing pyproject-hooks (1.2.0)
#   - Installing requests-oauthlib (2.0.0)
#   - Installing starlette (0.38.6)
#   - Installing uvloop (0.20.0): Downloading... 0%
#   - Installing watchfiles (0.24.0): Downloading... 0%
#   - Installing websockets (13.1): Downloading... 0%
#   - Installing durationpy (0.9)
#   - Installing flatbuffers (24.3.25)
#   - Installing google-auth (2.35.0)
#   - Installing httptools (0.6.1)
#   - Installing monotonic (1.6)
#   - Installing opentelemetry-instrumentation-asgi (0.45b0)
#   - Installing pyproject-hooks (1.2.0)
#   - Installing requests-oauthlib (2.0.0)
#   - Installing starlette (0.38.6)
#   - Installing uvloop (0.20.0): Downloading... 0%
#   - Installing watchfiles (0.24.0): Downloading... 0%
#   - Installing websockets (13.1): Downloading... 0%
#   - Installing coloredlogs (15.0.1): Downloading... 0%
#   - Installing durationpy (0.9)
#   - Installing flatbuffers (24.3.25)
#   - Installing google-auth (2.35.0)
#   - Installing httptools (0.6.1)
#   - Installing monotonic (1.6)
#   - Installing opentelemetry-instrumentation-asgi (0.45b0)
#   - Installing pyproject-hooks (1.2.0)
#   - Installing requests-oauthlib (2.0.0)
#   - Installing starlette (0.38.6)
#   - Installing uvloop (0.20.0): Downloading... 0%
#   - Installing watchfiles (0.24.0): Downloading... 0%
#   - Installing websockets (13.1): Downloading... 0%
#   - Installing coloredlogs (15.0.1): Downloading... 0%
#   - Installing durationpy (0.9)
#   - Installing flatbuffers (24.3.25)
#   - Installing google-auth (2.35.0)
#   - Installing httptools (0.6.1)
#   - Installing monotonic (1.6)
#   - Installing opentelemetry-instrumentation-asgi (0.45b0)
#   - Installing pyproject-hooks (1.2.0)
#   - Installing requests-oauthlib (2.0.0)
#   - Installing starlette (0.38.6)
#   - Installing uvloop (0.20.0): Downloading... 0%
#   - Installing watchfiles (0.24.0): Downloading... 0%
#   - Installing websockets (13.1): Downloading... 0%
#   - Installing backoff (2.2.1): Downloading... 100%
#   - Installing coloredlogs (15.0.1): Downloading... 0%
#   - Installing durationpy (0.9)
#   - Installing flatbuffers (24.3.25)
#   - Installing google-auth (2.35.0)
#   - Installing httptools (0.6.1)
#   - Installing monotonic (1.6)
#   - Installing opentelemetry-instrumentation-asgi (0.45b0)
#   - Installing pyproject-hooks (1.2.0)
#   - Installing requests-oauthlib (2.0.0)
#   - Installing starlette (0.38.6)
#   - Installing uvloop (0.20.0): Downloading... 0%
#   - Installing watchfiles (0.24.0): Downloading... 0%
#   - Installing websockets (13.1): Downloading... 0%
#   - Installing websockets (13.1): Downloading... 100%
#   - Installing coloredlogs (15.0.1): Downloading... 0%
#   - Installing durationpy (0.9)
#   - Installing flatbuffers (24.3.25)
#   - Installing google-auth (2.35.0)
#   - Installing httptools (0.6.1)
#   - Installing monotonic (1.6)
#   - Installing opentelemetry-instrumentation-asgi (0.45b0)
#   - Installing pyproject-hooks (1.2.0)
#   - Installing requests-oauthlib (2.0.0)
#   - Installing starlette (0.38.6)
#   - Installing uvloop (0.20.0): Downloading... 0%
#   - Installing watchfiles (0.24.0): Downloading... 0%
#   - Installing websockets (13.1): Downloading... 100%
#   - Installing backoff (2.2.1): Installing...
#   - Installing coloredlogs (15.0.1): Downloading... 0%
#   - Installing durationpy (0.9)
#   - Installing flatbuffers (24.3.25)
#   - Installing google-auth (2.35.0)
#   - Installing httptools (0.6.1)
#   - Installing monotonic (1.6)
#   - Installing opentelemetry-instrumentation-asgi (0.45b0)
#   - Installing pyproject-hooks (1.2.0)
#   - Installing requests-oauthlib (2.0.0)
#   - Installing starlette (0.38.6)
#   - Installing uvloop (0.20.0): Downloading... 0%
#   - Installing watchfiles (0.24.0): Downloading... 0%
#   - Installing websockets (13.1): Downloading... 100%
#   - Installing websockets (13.1): Installing...
#   - Installing coloredlogs (15.0.1): Downloading... 0%
#   - Installing durationpy (0.9)
#   - Installing flatbuffers (24.3.25)
#   - Installing google-auth (2.35.0)
#   - Installing httptools (0.6.1)
#   - Installing monotonic (1.6)
#   - Installing opentelemetry-instrumentation-asgi (0.45b0)
#   - Installing pyproject-hooks (1.2.0)
#   - Installing requests-oauthlib (2.0.0)
#   - Installing starlette (0.38.6)
#   - Installing uvloop (0.20.0): Downloading... 0%
#   - Installing watchfiles (0.24.0): Downloading... 0%
#   - Installing websockets (13.1): Installing...
#   - Installing backoff (2.2.1)
#   - Installing coloredlogs (15.0.1): Downloading... 0%
#   - Installing durationpy (0.9)
#   - Installing flatbuffers (24.3.25)
#   - Installing google-auth (2.35.0)
#   - Installing httptools (0.6.1)
#   - Installing monotonic (1.6)
#   - Installing opentelemetry-instrumentation-asgi (0.45b0)
#   - Installing pyproject-hooks (1.2.0)
#   - Installing requests-oauthlib (2.0.0)
#   - Installing starlette (0.38.6)
#   - Installing uvloop (0.20.0): Downloading... 0%
#   - Installing watchfiles (0.24.0): Downloading... 0%
#   - Installing websockets (13.1): Installing...
#   - Installing durationpy (0.9)
#   - Installing flatbuffers (24.3.25)
#   - Installing google-auth (2.35.0)
#   - Installing httptools (0.6.1)
#   - Installing monotonic (1.6)
#   - Installing opentelemetry-instrumentation-asgi (0.45b0)
#   - Installing pyproject-hooks (1.2.0)
#   - Installing requests-oauthlib (2.0.0)
#   - Installing starlette (0.38.6)
#   - Installing uvloop (0.20.0): Downloading... 0%
#   - Installing watchfiles (0.24.0): Downloading... 0%
#   - Installing websockets (13.1): Installing...
#   - Installing coloredlogs (15.0.1): Downloading... 100%
#   - Installing durationpy (0.9)
#   - Installing flatbuffers (24.3.25)
#   - Installing google-auth (2.35.0)
#   - Installing httptools (0.6.1)
#   - Installing monotonic (1.6)
#   - Installing opentelemetry-instrumentation-asgi (0.45b0)
#   - Installing pyproject-hooks (1.2.0)
#   - Installing requests-oauthlib (2.0.0)
#   - Installing starlette (0.38.6)
#   - Installing uvloop (0.20.0): Downloading... 0%
#   - Installing watchfiles (0.24.0): Downloading... 0%
#   - Installing websockets (13.1): Installing...
#   - Installing durationpy (0.9)
#   - Installing flatbuffers (24.3.25)
#   - Installing google-auth (2.35.0)
#   - Installing httptools (0.6.1)
#   - Installing monotonic (1.6)
#   - Installing opentelemetry-instrumentation-asgi (0.45b0)
#   - Installing pyproject-hooks (1.2.0)
#   - Installing requests-oauthlib (2.0.0)
#   - Installing starlette (0.38.6)
#   - Installing uvloop (0.20.0): Downloading... 0%
#   - Installing watchfiles (0.24.0): Downloading... 0%
#   - Installing websockets (13.1): Installing...
#   - Installing coloredlogs (15.0.1): Installing...
#   - Installing durationpy (0.9)
#   - Installing flatbuffers (24.3.25)
#   - Installing google-auth (2.35.0)
#   - Installing httptools (0.6.1)
#   - Installing monotonic (1.6)
#   - Installing opentelemetry-instrumentation-asgi (0.45b0)
#   - Installing pyproject-hooks (1.2.0)
#   - Installing requests-oauthlib (2.0.0)
#   - Installing starlette (0.38.6)
#   - Installing uvloop (0.20.0): Downloading... 0%
#   - Installing watchfiles (0.24.0): Downloading... 0%
#   - Installing websockets (13.1): Installing...
#   - Installing websockets (13.1): Installing...
#   - Installing watchfiles (0.24.0): Downloading... 100%
#   - Installing websockets (13.1): Installing...
#   - Installing websockets (13.1): Installing...
#   - Installing watchfiles (0.24.0): Installing...
#   - Installing websockets (13.1): Installing...
#   - Installing durationpy (0.9)
#   - Installing flatbuffers (24.3.25)
#   - Installing google-auth (2.35.0)
#   - Installing httptools (0.6.1)
#   - Installing monotonic (1.6)
#   - Installing opentelemetry-instrumentation-asgi (0.45b0)
# ...
#   - Installing build (1.2.2)
#   - Installing chroma-hnswlib (0.7.6): Pending...
#   - Installing fastapi (0.115.0)
#   - Installing importlib-resources (6.4.5)
#   - Installing kubernetes (31.0.0): Downloading... 60%
#   - Installing mmh3 (5.0.1)
#   - Installing onnxruntime (1.19.2): Downloading... 0%
#   - Installing opentelemetry-instrumentation-fastapi (0.45b0)
#   - Installing overrides (7.7.0): Pending...
#   - Installing posthog (3.6.6)
#   - Installing pypika (0.48.9): Pending...
#   - Installing uvicorn (0.31.0)
#   - Installing bcrypt (4.2.0): Downloading... 0%
#   - Installing build (1.2.2)
#   - Installing chroma-hnswlib (0.7.6): Pending...
#   - Installing fastapi (0.115.0)
#   - Installing importlib-resources (6.4.5)
#   - Installing kubernetes (31.0.0): Downloading... 60%
#   - Installing mmh3 (5.0.1)
#   - Installing onnxruntime (1.19.2): Downloading... 0%
#   - Installing opentelemetry-instrumentation-fastapi (0.45b0)
#   - Installing overrides (7.7.0): Pending...
#   - Installing posthog (3.6.6)
#   - Installing pypika (0.48.9): Pending...
#   - Installing uvicorn (0.31.0)
#   - Installing fastapi (0.115.0)
#   - Installing importlib-resources (6.4.5)
#   - Installing kubernetes (31.0.0): Downloading... 60%
#   - Installing mmh3 (5.0.1)
#   - Installing onnxruntime (1.19.2): Downloading... 0%
#   - Installing opentelemetry-instrumentation-fastapi (0.45b0)
#   - Installing overrides (7.7.0): Pending...
#   - Installing posthog (3.6.6)
#   - Installing pypika (0.48.9): Pending...
#   - Installing uvicorn (0.31.0)
#   - Installing chroma-hnswlib (0.7.6): Downloading... 0%
#   - Installing fastapi (0.115.0)
#   - Installing importlib-resources (6.4.5)
#   - Installing kubernetes (31.0.0): Downloading... 60%
#   - Installing mmh3 (5.0.1)
#   - Installing onnxruntime (1.19.2): Downloading... 0%
#   - Installing opentelemetry-instrumentation-fastapi (0.45b0)
#   - Installing overrides (7.7.0): Pending...
#   - Installing posthog (3.6.6)
#   - Installing pypika (0.48.9): Pending...
#   - Installing uvicorn (0.31.0)
#   - Installing posthog (3.6.6)
#   - Installing pypika (0.48.9): Pending...
#   - Installing uvicorn (0.31.0)
#   - Installing overrides (7.7.0): Installing...
#   - Installing posthog (3.6.6)
#   - Installing pypika (0.48.9): Pending...
#   - Installing uvicorn (0.31.0)
#   - Installing posthog (3.6.6)
#   - Installing pypika (0.48.9): Pending...
#   - Installing uvicorn (0.31.0)
#   - Installing overrides (7.7.0)
#   - Installing posthog (3.6.6)
#   - Installing pypika (0.48.9): Pending...
#   - Installing uvicorn (0.31.0)
#   - Installing opentelemetry-instrumentation-fastapi (0.45b0)
#   - Installing overrides (7.7.0)
#   - Installing posthog (3.6.6)
#   - Installing pypika (0.48.9): Pending...
#   - Installing uvicorn (0.31.0)
#   - Installing onnxruntime (1.19.2): Downloading... 20%
#   - Installing opentelemetry-instrumentation-fastapi (0.45b0)
#   - Installing overrides (7.7.0)
#   - Installing posthog (3.6.6)
#   - Installing pypika (0.48.9): Pending...
#   - Installing uvicorn (0.31.0)
#   - Installing mmh3 (5.0.1)
#   - Installing onnxruntime (1.19.2): Downloading... 20%
#   - Installing opentelemetry-instrumentation-fastapi (0.45b0)
#   - Installing overrides (7.7.0)
#   - Installing posthog (3.6.6)
#   - Installing pypika (0.48.9): Pending...
#   - Installing uvicorn (0.31.0)
#   - Installing kubernetes (31.0.0): Downloading... 100%
#   - Installing mmh3 (5.0.1)
#   - Installing onnxruntime (1.19.2): Downloading... 20%
#   - Installing opentelemetry-instrumentation-fastapi (0.45b0)
#   - Installing overrides (7.7.0)
#   - Installing posthog (3.6.6)
#   - Installing pypika (0.48.9): Pending...
#   - Installing uvicorn (0.31.0)
#   - Installing mmh3 (5.0.1)
#   - Installing onnxruntime (1.19.2): Downloading... 20%
#   - Installing opentelemetry-instrumentation-fastapi (0.45b0)
#   - Installing overrides (7.7.0)
#   - Installing posthog (3.6.6)
#   - Installing pypika (0.48.9): Pending...
#   - Installing uvicorn (0.31.0)
#   - Installing kubernetes (31.0.0): Installing...
#   - Installing mmh3 (5.0.1)
#   - Installing onnxruntime (1.19.2): Downloading... 20%
#   - Installing opentelemetry-instrumentation-fastapi (0.45b0)
#   - Installing overrides (7.7.0)
#   - Installing posthog (3.6.6)
#   - Installing pypika (0.48.9): Pending...
#   - Installing uvicorn (0.31.0)
#   - Installing uvicorn (0.31.0)
#   - Installing pypika (0.48.9): Downloading... 0%
#   - Installing uvicorn (0.31.0)
#   - Installing fastapi (0.115.0)
#   - Installing importlib-resources (6.4.5)
#   - Installing kubernetes (31.0.0): Installing...
#   - Installing mmh3 (5.0.1)
#   - Installing onnxruntime (1.19.2): Downloading... 20%
#   - Installing opentelemetry-instrumentation-fastapi (0.45b0)
#   - Installing overrides (7.7.0)
#   - Installing posthog (3.6.6)
#   - Installing pypika (0.48.9): Downloading... 0%
#   - Installing uvicorn (0.31.0)
#   - Installing chroma-hnswlib (0.7.6): Downloading... 90%
#   - Installing fastapi (0.115.0)
#   - Installing importlib-resources (6.4.5)
#   - Installing kubernetes (31.0.0): Installing...
#   - Installing mmh3 (5.0.1)
#   - Installing onnxruntime (1.19.2): Downloading... 20%
#   - Installing opentelemetry-instrumentation-fastapi (0.45b0)
#   - Installing overrides (7.7.0)
#   - Installing posthog (3.6.6)
#   - Installing pypika (0.48.9): Downloading... 0%
#   - Installing uvicorn (0.31.0)
#   - Installing build (1.2.2)
#   - Installing chroma-hnswlib (0.7.6): Downloading... 90%
#   - Installing fastapi (0.115.0)
#   - Installing importlib-resources (6.4.5)
#   - Installing kubernetes (31.0.0): Installing...
#   - Installing mmh3 (5.0.1)
#   - Installing onnxruntime (1.19.2): Downloading... 20%
#   - Installing opentelemetry-instrumentation-fastapi (0.45b0)
#   - Installing overrides (7.7.0)
#   - Installing posthog (3.6.6)
#   - Installing pypika (0.48.9): Downloading... 0%
#   - Installing uvicorn (0.31.0)
#   - Installing bcrypt (4.2.0): Downloading... 20%
#   - Installing build (1.2.2)
#   - Installing chroma-hnswlib (0.7.6): Downloading... 90%
#   - Installing fastapi (0.115.0)
#   - Installing importlib-resources (6.4.5)
#   - Installing kubernetes (31.0.0): Installing...
#   - Installing mmh3 (5.0.1)
#   - Installing onnxruntime (1.19.2): Downloading... 20%
#   - Installing opentelemetry-instrumentation-fastapi (0.45b0)
#   - Installing overrides (7.7.0)
#   - Installing posthog (3.6.6)
#   - Installing pypika (0.48.9): Downloading... 0%
#   - Installing uvicorn (0.31.0)
#   - Installing uvicorn (0.31.0)
#   - Installing pypika (0.48.9): Downloading... 100%
#   - Installing uvicorn (0.31.0)
#   - Installing fastapi (0.115.0)
#   - Installing importlib-resources (6.4.5)
#   - Installing kubernetes (31.0.0): Installing...
#   - Installing mmh3 (5.0.1)
#   - Installing onnxruntime (1.19.2): Downloading... 20%
#   - Installing opentelemetry-instrumentation-fastapi (0.45b0)
#   - Installing overrides (7.7.0)
#   - Installing posthog (3.6.6)
#   - Installing pypika (0.48.9): Downloading... 100%
#   - Installing uvicorn (0.31.0)
#   - Installing chroma-hnswlib (0.7.6): Downloading... 100%
#   - Installing fastapi (0.115.0)
#   - Installing importlib-resources (6.4.5)
#   - Installing kubernetes (31.0.0): Installing...
#   - Installing mmh3 (5.0.1)
#   - Installing onnxruntime (1.19.2): Downloading... 20%
#   - Installing opentelemetry-instrumentation-fastapi (0.45b0)
#   - Installing overrides (7.7.0)
#   - Installing posthog (3.6.6)
#   - Installing pypika (0.48.9): Downloading... 100%
#   - Installing uvicorn (0.31.0)
#   - Installing uvicorn (0.31.0)
#   - Installing pypika (0.48.9): Preparing...
#   - Installing uvicorn (0.31.0)
#   - Installing fastapi (0.115.0)
#   - Installing importlib-resources (6.4.5)
#   - Installing kubernetes (31.0.0): Installing...
#   - Installing mmh3 (5.0.1)
#   - Installing onnxruntime (1.19.2): Downloading... 20%
#   - Installing opentelemetry-instrumentation-fastapi (0.45b0)
#   - Installing overrides (7.7.0)
#   - Installing posthog (3.6.6)
#   - Installing pypika (0.48.9): Preparing...
#   - Installing uvicorn (0.31.0)
#   - Installing chroma-hnswlib (0.7.6): Installing...
#   - Installing fastapi (0.115.0)
#   - Installing importlib-resources (6.4.5)
#   - Installing kubernetes (31.0.0): Installing...
#   - Installing mmh3 (5.0.1)
#   - Installing onnxruntime (1.19.2): Downloading... 20%
#   - Installing opentelemetry-instrumentation-fastapi (0.45b0)
#   - Installing overrides (7.7.0)
#   - Installing posthog (3.6.6)
#   - Installing pypika (0.48.9): Preparing...
#   - Installing uvicorn (0.31.0)
#   - Installing fastapi (0.115.0)
#   - Installing importlib-resources (6.4.5)
#   - Installing kubernetes (31.0.0): Installing...
#   - Installing mmh3 (5.0.1)
#   - Installing onnxruntime (1.19.2): Downloading... 20%
#   - Installing opentelemetry-instrumentation-fastapi (0.45b0)
#   - Installing overrides (7.7.0)
#   - Installing posthog (3.6.6)
#   - Installing pypika (0.48.9): Preparing...
#   - Installing uvicorn (0.31.0)
#   - Installing chroma-hnswlib (0.7.6)
#   - Installing fastapi (0.115.0)
#   - Installing importlib-resources (6.4.5)
#   - Installing kubernetes (31.0.0): Installing...
#   - Installing mmh3 (5.0.1)
#   - Installing onnxruntime (1.19.2): Downloading... 20%
#   - Installing opentelemetry-instrumentation-fastapi (0.45b0)
#   - Installing overrides (7.7.0)
#   - Installing posthog (3.6.6)
#   - Installing pypika (0.48.9): Preparing...
#   - Installing uvicorn (0.31.0)
#   - Installing opentelemetry-instrumentation-fastapi (0.45b0)
#   - Installing overrides (7.7.0)
#   - Installing posthog (3.6.6)
#   - Installing pypika (0.48.9): Preparing...
#   - Installing uvicorn (0.31.0)
#   - Installing onnxruntime (1.19.2): Downloading... 40%
#   - Installing opentelemetry-instrumentation-fastapi (0.45b0)
#   - Installing overrides (7.7.0)
#   - Installing posthog (3.6.6)
#   - Installing pypika (0.48.9): Preparing...
#   - Installing uvicorn (0.31.0)
#   - Installing build (1.2.2)
#   - Installing chroma-hnswlib (0.7.6)
#   - Installing fastapi (0.115.0)
#   - Installing importlib-resources (6.4.5)
#   - Installing kubernetes (31.0.0): Installing...
#   - Installing mmh3 (5.0.1)
#   - Installing onnxruntime (1.19.2): Downloading... 40%
#   - Installing opentelemetry-instrumentation-fastapi (0.45b0)
#   - Installing overrides (7.7.0)
#   - Installing posthog (3.6.6)
#   - Installing pypika (0.48.9): Preparing...
#   - Installing uvicorn (0.31.0)
#   - Installing bcrypt (4.2.0): Downloading... 100%
#   - Installing build (1.2.2)
#   - Installing chroma-hnswlib (0.7.6)
#   - Installing fastapi (0.115.0)
#   - Installing importlib-resources (6.4.5)
#   - Installing kubernetes (31.0.0): Installing...
#   - Installing mmh3 (5.0.1)
#   - Installing onnxruntime (1.19.2): Downloading... 40%
#   - Installing opentelemetry-instrumentation-fastapi (0.45b0)
#   - Installing overrides (7.7.0)
#   - Installing posthog (3.6.6)
#   - Installing pypika (0.48.9): Preparing...
#   - Installing uvicorn (0.31.0)
#   - Installing build (1.2.2)
#   - Installing chroma-hnswlib (0.7.6)
#   - Installing fastapi (0.115.0)
#   - Installing importlib-resources (6.4.5)
#   - Installing kubernetes (31.0.0): Installing...
#   - Installing mmh3 (5.0.1)
#   - Installing onnxruntime (1.19.2): Downloading... 40%
#   - Installing opentelemetry-instrumentation-fastapi (0.45b0)
#   - Installing overrides (7.7.0)
#   - Installing posthog (3.6.6)
#   - Installing pypika (0.48.9): Preparing...
#   - Installing uvicorn (0.31.0)
#   - Installing bcrypt (4.2.0): Installing...
#   - Installing build (1.2.2)
#   - Installing chroma-hnswlib (0.7.6)
#   - Installing fastapi (0.115.0)
#   - Installing importlib-resources (6.4.5)
#   - Installing kubernetes (31.0.0): Installing...
#   - Installing mmh3 (5.0.1)
#   - Installing onnxruntime (1.19.2): Downloading... 40%
#   - Installing opentelemetry-instrumentation-fastapi (0.45b0)
#   - Installing overrides (7.7.0)
#   - Installing posthog (3.6.6)
#   - Installing pypika (0.48.9): Preparing...
#   - Installing uvicorn (0.31.0)
#   - Installing build (1.2.2)
#   - Installing chroma-hnswlib (0.7.6)
#   - Installing fastapi (0.115.0)
#   - Installing importlib-resources (6.4.5)
#   - Installing kubernetes (31.0.0): Installing...
#   - Installing mmh3 (5.0.1)
#   - Installing onnxruntime (1.19.2): Downloading... 40%
#   - Installing opentelemetry-instrumentation-fastapi (0.45b0)
#   - Installing overrides (7.7.0)
#   - Installing posthog (3.6.6)
#   - Installing pypika (0.48.9): Preparing...
#   - Installing uvicorn (0.31.0)
#   - Installing bcrypt (4.2.0)
#   - Installing build (1.2.2)
#   - Installing chroma-hnswlib (0.7.6)
#   - Installing fastapi (0.115.0)
#   - Installing importlib-resources (6.4.5)
#   - Installing kubernetes (31.0.0): Installing...
#   - Installing mmh3 (5.0.1)
#   - Installing onnxruntime (1.19.2): Downloading... 40%
#   - Installing opentelemetry-instrumentation-fastapi (0.45b0)
#   - Installing overrides (7.7.0)
#   - Installing posthog (3.6.6)
#   - Installing pypika (0.48.9): Preparing...
#   - Installing uvicorn (0.31.0)
#   - Installing mmh3 (5.0.1)
#   - Installing onnxruntime (1.19.2): Downloading... 40%
#   - Installing opentelemetry-instrumentation-fastapi (0.45b0)
#   - Installing overrides (7.7.0)
#   - Installing posthog (3.6.6)
#   - Installing pypika (0.48.9): Preparing...
#   - Installing uvicorn (0.31.0)
#   - Installing kubernetes (31.0.0)
#   - Installing mmh3 (5.0.1)
#   - Installing onnxruntime (1.19.2): Downloading... 40%
#   - Installing opentelemetry-instrumentation-fastapi (0.45b0)
#   - Installing overrides (7.7.0)
#   - Installing posthog (3.6.6)
#   - Installing pypika (0.48.9): Preparing...
#   - Installing uvicorn (0.31.0)
#   - Installing opentelemetry-instrumentation-fastapi (0.45b0)
#   - Installing overrides (7.7.0)
#   - Installing posthog (3.6.6)
#   - Installing pypika (0.48.9): Preparing...
#   - Installing uvicorn (0.31.0)
#   - Installing onnxruntime (1.19.2): Downloading... 80%
#   - Installing opentelemetry-instrumentation-fastapi (0.45b0)
#   - Installing overrides (7.7.0)
#   - Installing posthog (3.6.6)
#   - Installing pypika (0.48.9): Preparing...
#   - Installing uvicorn (0.31.0)
#   - Installing opentelemetry-instrumentation-fastapi (0.45b0)
#   - Installing overrides (7.7.0)
#   - Installing posthog (3.6.6)
#   - Installing pypika (0.48.9): Preparing...
#   - Installing uvicorn (0.31.0)
#   - Installing onnxruntime (1.19.2): Downloading... 100%
#   - Installing opentelemetry-instrumentation-fastapi (0.45b0)
#   - Installing overrides (7.7.0)
#   - Installing posthog (3.6.6)
#   - Installing pypika (0.48.9): Preparing...
#   - Installing uvicorn (0.31.0)
#   - Installing opentelemetry-instrumentation-fastapi (0.45b0)
#   - Installing overrides (7.7.0)
#   - Installing posthog (3.6.6)
#   - Installing pypika (0.48.9): Preparing...
#   - Installing uvicorn (0.31.0)
#   - Installing onnxruntime (1.19.2): Installing...
#   - Installing opentelemetry-instrumentation-fastapi (0.45b0)
#   - Installing overrides (7.7.0)
#   - Installing posthog (3.6.6)
#   - Installing pypika (0.48.9): Preparing...
#   - Installing uvicorn (0.31.0)
#   - Installing opentelemetry-instrumentation-fastapi (0.45b0)
#   - Installing overrides (7.7.0)
#   - Installing posthog (3.6.6)
#   - Installing pypika (0.48.9): Preparing...
#   - Installing uvicorn (0.31.0)
#   - Installing onnxruntime (1.19.2)
#   - Installing opentelemetry-instrumentation-fastapi (0.45b0)
#   - Installing overrides (7.7.0)
#   - Installing posthog (3.6.6)
#   - Installing pypika (0.48.9): Preparing...
#   - Installing uvicorn (0.31.0)
#   - Installing uvicorn (0.31.0)
#   - Installing pypika (0.48.9): Installing...
#   - Installing uvicorn (0.31.0)
#   - Installing uvicorn (0.31.0)
#   - Installing pypika (0.48.9)
#   - Installing uvicorn (0.31.0)
#   - Installing chromadb (0.5.11): Pending...
#   - Installing chromadb (0.5.11): Downloading... 0%
#   - Installing chromadb (0.5.11): Downloading... 100%
#   - Installing chromadb (0.5.11): Installing...
#   - Installing chromadb (0.5.11)
#   - Installing llama-index-vector-stores-chroma (0.2.0): Pending...
#   - Installing llama-index-vector-stores-chroma (0.2.0): Downloading... 0%
#   - Installing llama-index-vector-stores-chroma (0.2.0): Downloading... 100%
#   - Installing llama-index-vector-stores-chroma (0.2.0): Installing...
# Installing /Users/thomaschang/Library/Caches/pypoetry/virtualenvs/rag-techniques-EJ0Etk4F-py3.11/lib/python3.11/site-packages/llama_index/py.typed over existing file
#   - Installing llama-index-vector-stores-chroma (0.2.0)
#
# Writing lock file

# %%
# !poetry add python-dotenv
# Out:
# The following packages are already present in the pyproject.toml and will be skipped:
#
#   - python-dotenv
#
# If you want to update it to the latest compatible version, you can use `poetry update package`.
# If you prefer to upgrade it to the latest available version, you can use `poetry add package@latest`.
#
# Nothing to add.

# %% [markdown]
# ###  Import Libraries and enviornment variables

# %%
import os
from dotenv.main import load_dotenv

# Load environment variables from '.env' file
load_dotenv()

os.environ['OPENAI_API_KEY'] = os.getenv("OPENAI_API_KEY")

# %% [markdown]
# ### Load documents

# %%
from llama_index.readers.web import SimpleWebPageReader
from llama_index.core.node_parser import (
    SentenceSplitter,
    SemanticSplitterNodeParser,
)


urls = [
    "https://www.deeplearning.ai/the-batch/how-agents-can-improve-llm-performance/?ref=dl-staging-website.ghost.io",
    "https://www.deeplearning.ai/the-batch/agentic-design-patterns-part-2-reflection/?ref=dl-staging-website.ghost.io",
    "https://www.deeplearning.ai/the-batch/agentic-design-patterns-part-3-tool-use/?ref=dl-staging-website.ghost.io",
    "https://www.deeplearning.ai/the-batch/agentic-design-patterns-part-4-planning/?ref=dl-staging-website.ghost.io",
    "https://www.deeplearning.ai/the-batch/agentic-design-patterns-part-5-multi-agent-collaboration/?ref=dl-staging-website.ghost.io"
]

loaded_docs = SimpleWebPageReader(html_to_text=True).load_data(urls)

# %% [markdown]
# ### Create vector store

# %% [markdown]
# #### Create chroma vector store if it doesn't exist

# %%
from dotenv import dotenv_values
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from dotenv import dotenv_values
#
# ModuleNotFoundError: No module named 'dotenv'

# %%
import chromadb
chroma_client = chromadb.Client()
chroma_collection = chroma_client.create_collection("reliable_rag")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~/Library/Caches/pypoetry/virtualenvs/rag-techniques-EJ0Etk4F-py3.11/lib/python3.11/site-packages/pydantic/v1/env_settings.py:330, in read_env_file(file_path, encoding, case_sensitive)
#     329 try:
# --> 330     from dotenv import dotenv_values
#     331 except ImportError as e:
#
# ImportError: cannot import name 'dotenv_values' from 'dotenv' (/Users/thomaschang/Library/Caches/pypoetry/virtualenvs/rag-techniques-EJ0Etk4F-py3.11/lib/python3.11/site-packages/dotenv/__init__.py)
#
# The above exception was the direct cause of the following exception:
#
# ImportError                               Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 import chromadb
#       2 chroma_client = chromadb.Client()
#       3 chroma_collection = chroma_client.create_collection("reliable_rag")
#
# File ~/Library/Caches/pypoetry/virtualenvs/rag-techniques-EJ0Etk4F-py3.11/lib/python3.11/site-packages/chromadb/__init__.py:3
#       1 from typing import Dict, Optional
#       2 import logging
# ----> 3 from chromadb.api.client import Client as ClientCreator
#       4 from chromadb.api.client import AdminClient as AdminClientCreator
#       5 from chromadb.api.async_client import AsyncClient as AsyncClientCreator
#
# File ~/Library/Caches/pypoetry/virtualenvs/rag-techniques-EJ0Etk4F-py3.11/lib/python3.11/site-packages/chromadb/api/client.py:8
#       6 from chromadb.api import AdminAPI, ClientAPI, ServerAPI
#       7 from chromadb.api.configuration import CollectionConfiguration
# ----> 8 from chromadb.api.shared_system_client import SharedSystemClient
#       9 from chromadb.api.types import (
#      10     CollectionMetadata,
#      11     DataLoader,
#    (...)
#      22     URIs,
#      23 )
#      24 from chromadb.config import Settings, System
#
# File ~/Library/Caches/pypoetry/virtualenvs/rag-techniques-EJ0Etk4F-py3.11/lib/python3.11/site-packages/chromadb/api/shared_system_client.py:10
#       6 from chromadb.telemetry.product import ProductTelemetryClient
#       7 from chromadb.telemetry.product.events import ClientStartEvent
# ---> 10 class SharedSystemClient:
#      11     _identifier_to_system: ClassVar[Dict[str, System]] = {}
#      12     _identifier: str
#
# File ~/Library/Caches/pypoetry/virtualenvs/rag-techniques-EJ0Etk4F-py3.11/lib/python3.11/site-packages/chromadb/api/shared_system_client.py:16, in SharedSystemClient()
#      11 _identifier_to_system: ClassVar[Dict[str, System]] = {}
#      12 _identifier: str
#      14 def __init__(
#      15     self,
# ---> 16     settings: Settings = Settings(),
#      17 ) -> None:
#      18     self._identifier = SharedSystemClient._get_identifier_from_settings(settings)
#      19     SharedSystemClient._create_system_if_not_exists(self._identifier, settings)
#
# File ~/Library/Caches/pypoetry/virtualenvs/rag-techniques-EJ0Etk4F-py3.11/lib/python3.11/site-packages/pydantic/v1/env_settings.py:41, in BaseSettings.__init__(__pydantic_self__, _env_file, _env_file_encoding, _env_nested_delimiter, _secrets_dir, **values)
#      31 def __init__(
#      32     __pydantic_self__,
#      33     _env_file: Optional[DotenvType] = env_file_sentinel,
#    (...)
#      38 ) -> None:
#      39     # Uses something other than `self` the first arg to allow "self" as a settable attribute
#      40     super().__init__(
# ---> 41         **__pydantic_self__._build_values(
#      42             values,
#      43             _env_file=_env_file,
#      44             _env_file_encoding=_env_file_encoding,
#      45             _env_nested_delimiter=_env_nested_delimiter,
#      46             _secrets_dir=_secrets_dir,
#      47         )
#      48     )
#
# File ~/Library/Caches/pypoetry/virtualenvs/rag-techniques-EJ0Etk4F-py3.11/lib/python3.11/site-packages/pydantic/v1/env_settings.py:76, in BaseSettings._build_values(self, init_kwargs, _env_file, _env_file_encoding, _env_nested_delimiter, _secrets_dir)
#      72 sources = self.__config__.customise_sources(
#      73     init_settings=init_settings, env_settings=env_settings, file_secret_settings=file_secret_settings
#      74 )
#      75 if sources:
# ---> 76     return deep_update(*reversed([source(self) for source in sources]))
#      77 else:
#      78     # no one should mean to do this, but I think returning an empty dict is marginally preferable
#      79     # to an informative error and much better than a confusing error
#      80     return {}
#
# File ~/Library/Caches/pypoetry/virtualenvs/rag-techniques-EJ0Etk4F-py3.11/lib/python3.11/site-packages/pydantic/v1/env_settings.py:76, in <listcomp>(.0)
#      72 sources = self.__config__.customise_sources(
#      73     init_settings=init_settings, env_settings=env_settings, file_secret_settings=file_secret_settings
#      74 )
#      75 if sources:
# ---> 76     return deep_update(*reversed([source(self) for source in sources]))
#      77 else:
#      78     # no one should mean to do this, but I think returning an empty dict is marginally preferable
#      79     # to an informative error and much better than a confusing error
#      80     return {}
#
# File ~/Library/Caches/pypoetry/virtualenvs/rag-techniques-EJ0Etk4F-py3.11/lib/python3.11/site-packages/pydantic/v1/env_settings.py:177, in EnvSettingsSource.__call__(self, settings)
#     174 else:
#     175     env_vars = {k.lower(): v for k, v in os.environ.items()}
# --> 177 dotenv_vars = self._read_env_files(settings.__config__.case_sensitive)
#     178 if dotenv_vars:
#     179     env_vars = {**dotenv_vars, **env_vars}
#
# File ~/Library/Caches/pypoetry/virtualenvs/rag-techniques-EJ0Etk4F-py3.11/lib/python3.11/site-packages/pydantic/v1/env_settings.py:226, in EnvSettingsSource._read_env_files(self, case_sensitive)
#     223     env_path = Path(env_file).expanduser()
#     224     if env_path.is_file():
#     225         dotenv_vars.update(
# --> 226             read_env_file(env_path, encoding=self.env_file_encoding, case_sensitive=case_sensitive)
#     227         )
#     229 return dotenv_vars
#
# File ~/Library/Caches/pypoetry/virtualenvs/rag-techniques-EJ0Etk4F-py3.11/lib/python3.11/site-packages/pydantic/v1/env_settings.py:332, in read_env_file(file_path, encoding, case_sensitive)
#     330     from dotenv import dotenv_values
#     331 except ImportError as e:
# --> 332     raise ImportError('python-dotenv is not installed, run `pip install pydantic[dotenv]`') from e
#     334 file_vars: Dict[str, Optional[str]] = dotenv_values(file_path, encoding=encoding or 'utf8')
#     335 if not case_sensitive:
#
# ImportError: python-dotenv is not installed, run `pip install pydantic[dotenv]`

# %% [markdown]
# ### Chunk the documents

# %%
from llama_index.embeddings.openai import OpenAIEmbedding

embed_model = OpenAIEmbedding()
splitter = SemanticSplitterNodeParser(
    buffer_size=1, breakpoint_percentile_threshold=95, embed_model=embed_model
)

nodes = splitter.get_nodes_from_documents(loaded_docs)

# %% [markdown]
# Store the chunks in Chroma

# %%
from llama_index.core import StorageContext
from llama_index.core import VectorStoreIndex
from llama_index.vector_stores.chroma import ChromaVectorStore


vector_store = ChromaVectorStore(chroma_collection=chroma_collection)
storage_context = StorageContext.from_defaults(vector_store=vector_store)
index = VectorStoreIndex(nodes, storage_context=storage_context)

# %%
retriever = index.as_retriever(similarity_top_k=2)

# %% [markdown]
# ### Question

# %%
question = "what are the differnt kind of agentic design patterns?"

# %% [markdown]
# ### Retrieve documents

# %%
docs = retriever.retrieve(question)

# %% [markdown]
# ### Check what our docs look like

# %%
print(docs[0])
